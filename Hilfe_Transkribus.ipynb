# %%
import requests
import json
from lxml import objectify, etree
from pprint import pprint

# %%
class Transkribus_API():

    def __init__(self, api_base_url="https://transkribus.eu/TrpServer/rest/"):
        self.cols = {}
        self.api_base_url = api_base_url
        self.session_id = False
        self.cache = False

    def _url(self, endpoint):
        """ Helper function that returns a full URL for requests to the REST API, 
            i.e. the API base URL + the relative path of the endpoint. """
        
        return self.api_base_url + endpoint    
    
    def login(self, username, password):
        """ Performs a login and stores the SESSIONID in the "session_id" variable
            of this class. """
        
        credentials = {"user": username,
                       "pw": password}
        response = requests.post(self._url("auth/login"), data=credentials)
        if response:
            r = objectify.fromstring(response.content)
            print(f"TRANSKRIBUS: User {r.firstname} {r.lastname} ({r.userId}) logged in successfully.")
            self.session_id = str(r.sessionId)
            return str(r.sessionId)
        else:
            print("TRANSKRIBUS: Login failed. HTTP status:", response.status_code)
            return False
    
    def logout(self):
        """ Logs out and sets the "session_id" variable to False. """
        
        cookies = dict(JSESSIONID=self.session_id)
        response = requests.post(self._url("auth/logout"), cookies=cookies)
        if response:
            self.session_id = False
            print("TRANSKRIBUS: Logged out successfully.")
            return True
        else:
            print("TRANSKRIBUS: Logout failed. HTTP status:", response.status_code, response.content)
            return False

    def verify(self, username, password):
        """ Logs in and logs out to check whether the credentials
            are valid on the Transkribus server. 
            Returns True or False. """
        
        session_id = self.login(username, password)
        if session_id:
            self.logout(session_id)
            return True
        else: 
            return False        
        
    def request_endpoint(self, endpoint):
        """ Sends a GET request to a Transkribus API endpoint, the 
            "endpoint" argument being a relative path to the REST API endpoint

            Cf. the list of available endpoints:
            https://transkribus.eu/TrpServer/Swadl/wadl.html

            Depending on the content type (JSON or XML), 
            the function tries to decode the raw content of the response.
            It returns a json object or an "objectify" object (lxml). If
            the conversion fails the raw content is returned. """

        cookies = dict(JSESSIONID=self.session_id)
        
        response = requests.get(self._url(endpoint), cookies=cookies)

        if response:
            try:
                json = response.json()
                return json
            except:
                try:
                    xml = objectify.fromstring(response.content)
                    return xml
                except:
                    return response.content  # fallback option if the server returns just text
        else:
            print(f'TRANSKRIBUS: ERROR when requesting "{endpoint}". HTTP status:', response.status_code)
            return False
    
    # Convenience functions to query certain endpoints: 
    
    def get_collections(self):
        """ Get the metadata of the owner's collections. 
            Returns a dict if successful or False if not. """
        
        endpoint = "collections/list"
        collections = self.request_endpoint(endpoint)
        return collections if collections else False
    
    def get_documents_in_collection(self, colId):
        """ Get the metadata of a collection. 
            Returns a dict if successful or False if not.
            
            colId -- collection ID in Transkribus (int) """
        
        endpoint = f"collections/{colId}/list"
        documents = self.request_endpoint(endpoint)
        return documents if documents else False

    def get_pages_in_document(self, colId, docId):
        """ Get the basic metadata of the pages in a document. 
            Returns a dict if successful or False if not.
           
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) """
        
        endpoint = f"collections/{colId}/{docId}/pages"
        pages = self.request_endpoint(endpoint)
        return pages if pages else False
        
    def get_page_xml(self, colId, docId, pageNr):
        """ Get the XML content of a page. 
            Returns an "objectify" object (lxml) or False if not successful. 
            
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) 
            
            The returned object X has two attributes: X.Metadata and X.Page. 
            X.Page is empty if there are no transcripts yet. 
            If there exists a transcription X.Page has further attributes
            (i and j are list indices counting from 0):
            
            X.Page.Metadata
                  .ReadingOrder
                  .values()   -> list containing imgFileName, width (px), height (px)
                  .TextRegion[i].Coords.attrib['points']               -> coordinates of the whole text region (1)
                                .TextEquiv.Unicode                     -> utf-8 string of the transcription of the whole text region
                                .TextLine[j].Coords.attrib['points']   -> coordinates of this line (1) (2)
                                            .BaseLine.attrib['points'] -> coordinates of this baseline (2)
                                            .TextEquiv.Unicode         -> utf-8 string of the transcription
            
            (1) Instead of .attrib['points'] you can say .values()[0].
            (2) The line is a polygon around the line of text, the BaseLine is a line below the text.
            
            You can check for the existence of attributes: if hasattr(X.Page, "TextRegion")…
            Get a list of existing attributes: X.Page.__dict__

            """
        
        endpoint = f"collections/{colId}/{docId}/{pageNr}/text"
        page_xml = self.request_endpoint(endpoint)
        return page_xml if page_xml is not None else False
    
    def upload_page_xml(self, colId, docId, pageNr, new_status, page_xml):
        """ Upload page XML data to the Transkribus server using a POST request. 
            Returns True or False.
        
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) 
            new_status -- new_status of the page. Possible values are NEW, IN_PROGRESS, DONE, FINAL, GT. 
            
            tsId = transcript ID of the last version of this transcription (int).
            After the upload Transkribus will generate a new transcription Id and save 
            the old one as the 'parentTsId' of the new transcription. """

        # Get the transcript ID of the latest transcription:
        current_transcript = self.request_endpoint(f"collections/{colId}/{docId}/{pageNr}/curr")
        if current_transcript:
            tsId = current_transcript['tsId']
        else:
            return False
        
        headers = {'Content-Type': 'text/xml'} 
        cookies = dict(JSESSIONID=self.session_id)
        params = {'status': new_status,
                  'parent': tsId,
                  'overwrite': 'false'}
        # convert the page_xml object to a pretty utf-8 string:
        data = etree.tostring(page_xml, pretty_print=True, xml_declaration=True).decode("utf-8")

        response = requests.post(self._url(f"collections/{colId}/{docId}/{pageNr}/text"), 
                                 headers=headers,
                                 params=params,
                                 cookies=cookies, 
                                 data=data)

        if response:
            print(f"Uploaded page {colId}/{docId}/{pageNr} successfully: {response.status_code}")
            print(response.content.decode(encoding="utf-8"))
            return True
        else:
            print(f"ERROR while uploading {colId}/{docId}/{pageNr}: {response.status_code}")
            print(response.content.decode(encoding="utf-8"))
            return False
        
    def update_page_status(self, colId, docId, pageNr, new_status):
        """ Update the status of the transcript with the transcript ID tsId with new_status.
            Returns True or False. 
            
            colId -- collection ID in Transkribus (int) 
            docId -- document ID in Transkribus (int) 
            pageNr -- page ID in Transkribus (int) 
            new_status -- new_status of the page. Possible values are NEW, IN_PROGRESS, DONE, FINAL, GT. """

        # Get the transcript ID of the latest transcription:
        current_transcript = self.request_endpoint(f"collections/{colId}/{docId}/{pageNr}/curr")
        if current_transcript:
            tsId = current_transcript['tsId']
        else:
            return False
        
        cookies = dict(JSESSIONID=self.session_id)
        params = {'status': new_status}
        
        endpoint = f"collections/{colId}/{docId}/{pageNr}/{tsId}"
        response = requests.post(self._url(endpoint),
                                 params=params,
                                 cookies=cookies)
        
        if response:
            print(f"TRANSKRIBUS: Updated status of page {pageNr} to {new_status} in collection {colId}, document {docId}.")
            print(response.content.decode(encoding="utf-8"))
            return True
        else:
            print(f"TRANSKRIBUS: ERROR: Could not update status of page {pageNr} to {new_status} in collection {colId}, document {docId}.")
            print(response.content.decode(encoding="utf-8"))
            return False

# %%
#client = Transkribus_API()
#session_id = client.login("a12110417@unet.univie.ac.at", "=b@gMi4}:9;P?b'")
# Out:
# TRANSKRIBUS: User Sarah Bloos (192043) logged in successfully.

# %%
#client.get_collections()
# Out:
# [{'type': 'trpCollection',
#   'colId': 240344,
#   'colName': 'a12110417@unet.univie.ac.at Collection',
#   'description': 'a12110417@unet.univie.ac.at',
#   'crowdsourcing': False,
#   'elearning': False,
#   'pageId': 60726316,
#   'url': 'https://files.transkribus.eu/Get?fileType=view&id=DAEQZNPMDNXLWKBWOHOHPWDD',
#   'thumbUrl': 'https://files.transkribus.eu/Get?fileType=thumb&id=DAEQZNPMDNXLWKBWOHOHPWDD',
#   'nrOfDocuments': 2,
#   'role': 'Owner',
#   'accountingStatus': 1}]

# %%
#colId = 240344

# Get the metadata of all the documents in this collection:
#client.get_documents_in_collection(colId)
# Out:
# [{'type': 'trpDocMetadata',
#   'docId': 1620944,
#   'title': 'ABO_+Z25849202.pdf',
#   'uploadTimestamp': 1697809383282,
#   'uploader': 'a12110417@unet.univie.ac.at',
#   'uploaderId': 192043,
#   'nrOfPages': 146,
#   'pageId': 60726590,
#   'url': 'https://files.transkribus.eu/Get?fileType=view&id=XSHYUCVAMDHEVTGYNMZZLNXM',
#   'thumbUrl': 'https://files.transkribus.eu/Get?fileType=thumb&id=XSHYUCVAMDHEVTGYNMZZLNXM',
#   'status': 0,
#   'fimgStoreColl': 'TrpDoc_DEA_1620944',
#   'origDocId': 0,
#   'collectionList': {'colList': [{'colId': 240344,
#      'colName': 'a12110417@unet.univie.ac.at Collection',
#      'description': 'a12110417@unet.univie.ac.at',
#      'crowdsourcing': False,
#      'elearning': False,
#      'nrOfDocuments': 0}]},
#   'attributes': [],
#   'mainColId': 240344,
#   'isInMain': True}]

# %%
#DocId = 1620944

# %%
#client.get_pages_in_document(colId, DocId)
# Out:
# [{'pageId': 60726590,
#   'docId': 1620944,
#   'pageNr': 1,
#   'key': 'XSHYUCVAMDHEVTGYNMZZLNXM',
#   'imageId': 49050367,
#   'url': 'https://files.transkribus.eu/Get?id=XSHYUCVAMDHEVTGYNMZZLNXM&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XSHYUCVAMDHEVTGYNMZZLNXM&fileType=thumb',
#   'md5Sum': 'af1e13e6df99557ba41994501f0d8fad',
#   'fileSize': 405983,
#   'imgFileName': 'p001.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766257,
#      'parentTsId': -1,
#      'key': 'RSRKOWCRPLMDCPYWDSXPJWGH',
#      'pageId': 60726590,
#      'docId': 1620944,
#      'pageNr': 1,
#      'url': 'https://files.transkribus.eu/Get?id=RSRKOWCRPLMDCPYWDSXPJWGH',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'f9a015bf7a5e78e297fdbed8f491a16c',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p001.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:03.364+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.133+02:00'},
#  {'pageId': 60726591,
#   'docId': 1620944,
#   'pageNr': 2,
#   'key': 'GEKDIWSBKNNFTWUWXXYBCQXO',
#   'imageId': 49050368,
#   'url': 'https://files.transkribus.eu/Get?id=GEKDIWSBKNNFTWUWXXYBCQXO&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=GEKDIWSBKNNFTWUWXXYBCQXO&fileType=thumb',
#   'md5Sum': '58a32fe8050ddee1a918b1e3295f9a49',
#   'fileSize': 617141,
#   'imgFileName': 'p002.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766258,
#      'parentTsId': -1,
#      'key': 'XVTRSUNKQKTJXERFDUAISYNA',
#      'pageId': 60726591,
#      'docId': 1620944,
#      'pageNr': 2,
#      'url': 'https://files.transkribus.eu/Get?id=XVTRSUNKQKTJXERFDUAISYNA',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'a387cf7c2ccc548f9f99faa53a0bd8a5',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p002.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:04.022+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.269+02:00'},
#  {'pageId': 60726592,
#   'docId': 1620944,
#   'pageNr': 3,
#   'key': 'YVGAXCWKOPAJSNKUPTXGGIOE',
#   'imageId': 49050369,
#   'url': 'https://files.transkribus.eu/Get?id=YVGAXCWKOPAJSNKUPTXGGIOE&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=YVGAXCWKOPAJSNKUPTXGGIOE&fileType=thumb',
#   'md5Sum': 'a11991bc9f932d636078075b30f7161d',
#   'fileSize': 548036,
#   'imgFileName': 'p003.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766259,
#      'parentTsId': -1,
#      'key': 'SWSXSGJIBUPPMKUJGSOHLFAF',
#      'pageId': 60726592,
#      'docId': 1620944,
#      'pageNr': 3,
#      'url': 'https://files.transkribus.eu/Get?id=SWSXSGJIBUPPMKUJGSOHLFAF',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '9283b7a90fdd08cdc9005adc42d0f742',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p003.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:04.458+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:19.261+02:00'},
#  {'pageId': 60726593,
#   'docId': 1620944,
#   'pageNr': 4,
#   'key': 'SFAYXUEJQCBYWPTMANCEKFNN',
#   'imageId': 49050370,
#   'url': 'https://files.transkribus.eu/Get?id=SFAYXUEJQCBYWPTMANCEKFNN&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=SFAYXUEJQCBYWPTMANCEKFNN&fileType=thumb',
#   'md5Sum': 'e0d40d1506f9a2399be48e6fb6147f94',
#   'fileSize': 457818,
#   'imgFileName': 'p004.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766260,
#      'parentTsId': -1,
#      'key': 'TSGWMYWBPIXMRKZLVBZUWDAE',
#      'pageId': 60726593,
#      'docId': 1620944,
#      'pageNr': 4,
#      'url': 'https://files.transkribus.eu/Get?id=TSGWMYWBPIXMRKZLVBZUWDAE',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '716ee04b1d4d5cc01dcc94da515fa74f',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p004.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:04.907+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:19.313+02:00'},
#  {'pageId': 60726594,
#   'docId': 1620944,
#   'pageNr': 5,
#   'key': 'DGZIVTOMSRWQDZMXTKHXLEZA',
#   'imageId': 49050371,
#   'url': 'https://files.transkribus.eu/Get?id=DGZIVTOMSRWQDZMXTKHXLEZA&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=DGZIVTOMSRWQDZMXTKHXLEZA&fileType=thumb',
#   'md5Sum': '889512cce6f71ec12394243664609cfb',
#   'fileSize': 442730,
#   'imgFileName': 'p005.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766261,
#      'parentTsId': -1,
#      'key': 'CQZTCRVXWXANLTVEYUNPWXKA',
#      'pageId': 60726594,
#      'docId': 1620944,
#      'pageNr': 5,
#      'url': 'https://files.transkribus.eu/Get?id=CQZTCRVXWXANLTVEYUNPWXKA',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '3f14e222ebfd556676b4c4180a277441',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p005.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:05.333+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:19.387+02:00'},
#  {'pageId': 60726595,
#   'docId': 1620944,
#   'pageNr': 6,
#   'key': 'TDOOCPRNLOHPIXSHPTALSCTL',
#   'imageId': 49050372,
#   'url': 'https://files.transkribus.eu/Get?id=TDOOCPRNLOHPIXSHPTALSCTL&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=TDOOCPRNLOHPIXSHPTALSCTL&fileType=thumb',
#   'md5Sum': '7cf00ad0c578cec81f1dc6b4d3c91389',
#   'fileSize': 715941,
#   'imgFileName': 'p006.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163184,
#      'parentTsId': 137766263,
#      'key': 'FTMVDTCCZLAGRUAPNWDURQYK',
#      'pageId': 60726595,
#      'docId': 1620944,
#      'pageNr': 6,
#      'url': 'https://files.transkribus.eu/Get?id=FTMVDTCCZLAGRUAPNWDURQYK',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286038792,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'baf8d3e6a5cdf72b74412178ca066d2d',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 14,
#      'nrOfTranscribedLines': 14,
#      'nrOfWordsInLines': 31,
#      'nrOfWords': 31,
#      'nrOfTranscribedWords': 31,
#      'nrOfCharsInLines': 194,
#      'fileSize': 18685,
#      'fileName': 'p006.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:05.95+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:19.115+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.039+02:00'},
#  {'pageId': 60726596,
#   'docId': 1620944,
#   'pageNr': 7,
#   'key': 'GUDQPHRRCZOOXYKTDHRIOQAU',
#   'imageId': 49050373,
#   'url': 'https://files.transkribus.eu/Get?id=GUDQPHRRCZOOXYKTDHRIOQAU&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=GUDQPHRRCZOOXYKTDHRIOQAU&fileType=thumb',
#   'md5Sum': '4056d2645ba2a0df6f03eb86dd606471',
#   'fileSize': 482964,
#   'imgFileName': 'p007.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_7 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163185,
#      'parentTsId': 137766265,
#      'key': 'BETPGSHQTZKKXNZSJELXPRGL',
#      'pageId': 60726596,
#      'docId': 1620944,
#      'pageNr': 7,
#      'url': 'https://files.transkribus.eu/Get?id=BETPGSHQTZKKXNZSJELXPRGL',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286039126,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '8114fb4cddb81fe94f7b6d57347e7acf',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 3,
#      'nrOfTranscribedLines': 3,
#      'nrOfWordsInLines': 5,
#      'nrOfWords': 5,
#      'nrOfTranscribedWords': 5,
#      'nrOfCharsInLines': 20,
#      'fileSize': 4376,
#      'fileName': 'p007.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:07.195+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:19.301+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.028+02:00'},
#  {'pageId': 60726597,
#   'docId': 1620944,
#   'pageNr': 8,
#   'key': 'DKKYTUXZICXWZVMDUXIKLLEN',
#   'imageId': 49050374,
#   'url': 'https://files.transkribus.eu/Get?id=DKKYTUXZICXWZVMDUXIKLLEN&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=DKKYTUXZICXWZVMDUXIKLLEN&fileType=thumb',
#   'md5Sum': 'd0ce81555f17b586f0151fad182ae20e',
#   'fileSize': 755129,
#   'imgFileName': 'p008.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163186,
#      'parentTsId': 137936882,
#      'key': 'UGUOMILDEODSZDVXOVCQSTPK',
#      'pageId': 60726597,
#      'docId': 1620944,
#      'pageNr': 8,
#      'url': 'https://files.transkribus.eu/Get?id=UGUOMILDEODSZDVXOVCQSTPK',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286039317,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'a19968c9d8bc7132e2275804dd342538',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 21,
#      'nrOfTranscribedLines': 21,
#      'nrOfWordsInLines': 129,
#      'nrOfWords': 129,
#      'nrOfTranscribedWords': 129,
#      'nrOfCharsInLines': 702,
#      'fileSize': 51179,
#      'fileName': 'p008.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:07.716+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:19.515+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.743+02:00'},
#  {'pageId': 60726598,
#   'docId': 1620944,
#   'pageNr': 9,
#   'key': 'WPFEKQSWBRYZXLMCAXYGSVEQ',
#   'imageId': 49050375,
#   'url': 'https://files.transkribus.eu/Get?id=WPFEKQSWBRYZXLMCAXYGSVEQ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=WPFEKQSWBRYZXLMCAXYGSVEQ&fileType=thumb',
#   'md5Sum': '2cc67528b1c8ef6b51f702a0dd6571c1',
#   'fileSize': 905243,
#   'imgFileName': 'p009.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163187,
#      'parentTsId': 137936883,
#      'key': 'DPZOMYVUPZIPFVCSSTLXZTSL',
#      'pageId': 60726598,
#      'docId': 1620944,
#      'pageNr': 9,
#      'url': 'https://files.transkribus.eu/Get?id=DPZOMYVUPZIPFVCSSTLXZTSL',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286039531,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '3a970dbc166450f03b31d7968f0052a5',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 28,
#      'nrOfTranscribedLines': 28,
#      'nrOfWordsInLines': 202,
#      'nrOfWords': 202,
#      'nrOfTranscribedWords': 202,
#      'nrOfCharsInLines': 1055,
#      'fileSize': 76384,
#      'fileName': 'p009.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:08.11+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:19.816+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.09+02:00'},
#  {'pageId': 60726599,
#   'docId': 1620944,
#   'pageNr': 10,
#   'key': 'XHWRJMHPNXIVTGTJHIUTBEIL',
#   'imageId': 49050376,
#   'url': 'https://files.transkribus.eu/Get?id=XHWRJMHPNXIVTGTJHIUTBEIL&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XHWRJMHPNXIVTGTJHIUTBEIL&fileType=thumb',
#   'md5Sum': '0b983295cbc68f3f84183ef7183b8234',
#   'fileSize': 1001686,
#   'imgFileName': 'p010.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_10 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163188,
#      'parentTsId': 137936884,
#      'key': 'MCBTEOXCNMCSGMYUPDIPWSBB',
#      'pageId': 60726599,
#      'docId': 1620944,
#      'pageNr': 10,
#      'url': 'https://files.transkribus.eu/Get?id=MCBTEOXCNMCSGMYUPDIPWSBB',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286039832,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'ab9242db86cec2c3af0fffbc13145003',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 226,
#      'nrOfWords': 226,
#      'nrOfTranscribedWords': 226,
#      'nrOfCharsInLines': 1236,
#      'fileSize': 83842,
#      'fileName': 'p010.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:08.546+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:20.013+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.096+02:00'},
#  {'pageId': 60726600,
#   'docId': 1620944,
#   'pageNr': 11,
#   'key': 'XGHHIUDTHXTMZAWUUDRERSAW',
#   'imageId': 49050377,
#   'url': 'https://files.transkribus.eu/Get?id=XGHHIUDTHXTMZAWUUDRERSAW&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XGHHIUDTHXTMZAWUUDRERSAW&fileType=thumb',
#   'md5Sum': '527ad8039800bf1351d34e3e9b3d8fde',
#   'fileSize': 841977,
#   'imgFileName': 'p011.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_11 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163189,
#      'parentTsId': 137936885,
#      'key': 'DXWKCRBBGJJOWJOIMMZMLPUQ',
#      'pageId': 60726600,
#      'docId': 1620944,
#      'pageNr': 11,
#      'url': 'https://files.transkribus.eu/Get?id=DXWKCRBBGJJOWJOIMMZMLPUQ',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286040027,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'da0b447f318423df2956a26d8a45a962',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 202,
#      'nrOfWords': 202,
#      'nrOfTranscribedWords': 202,
#      'nrOfCharsInLines': 1143,
#      'fileSize': 77093,
#      'fileName': 'p011.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:08.979+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:20.227+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.756+02:00'},
#  {'pageId': 60726601,
#   'docId': 1620944,
#   'pageNr': 12,
#   'key': 'TYPVDESVENWQYEJCMYDKXLNR',
#   'imageId': 49050378,
#   'url': 'https://files.transkribus.eu/Get?id=TYPVDESVENWQYEJCMYDKXLNR&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=TYPVDESVENWQYEJCMYDKXLNR&fileType=thumb',
#   'md5Sum': 'ef58c49c900f400cc5804bad7f211e39',
#   'fileSize': 916295,
#   'imgFileName': 'p012.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163190,
#      'parentTsId': 137936886,
#      'key': 'DXVUMJYCQBJDXRJMAYRQTKLK',
#      'pageId': 60726601,
#      'docId': 1620944,
#      'pageNr': 12,
#      'url': 'https://files.transkribus.eu/Get?id=DXVUMJYCQBJDXRJMAYRQTKLK',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286040241,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '9a47fbc76641244cc615e3b128c23b9d',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 209,
#      'nrOfWords': 209,
#      'nrOfTranscribedWords': 209,
#      'nrOfCharsInLines': 1184,
#      'fileSize': 78867,
#      'fileName': 'p012.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:09.319+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:20.41+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.113+02:00'},
#  {'pageId': 60726602,
#   'docId': 1620944,
#   'pageNr': 13,
#   'key': 'WCJMDKVGQLYONUTPFSCQVXUJ',
#   'imageId': 49050379,
#   'url': 'https://files.transkribus.eu/Get?id=WCJMDKVGQLYONUTPFSCQVXUJ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=WCJMDKVGQLYONUTPFSCQVXUJ&fileType=thumb',
#   'md5Sum': '40345468720bf67f61349e73a35a69eb',
#   'fileSize': 928948,
#   'imgFileName': 'p013.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163191,
#      'parentTsId': 137936887,
#      'key': 'XOKVRBJHLJPLTRKKZRHDZGLE',
#      'pageId': 60726602,
#      'docId': 1620944,
#      'pageNr': 13,
#      'url': 'https://files.transkribus.eu/Get?id=XOKVRBJHLJPLTRKKZRHDZGLE',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286040423,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'c4e43dc3d265b2ebdde2d93d3b5bda2d',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 228,
#      'nrOfWords': 228,
#      'nrOfTranscribedWords': 228,
#      'nrOfCharsInLines': 1189,
#      'fileSize': 84616,
#      'fileName': 'p013.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:09.69+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:20.638+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.11+02:00'},
#  {'pageId': 60726603,
#   'docId': 1620944,
#   'pageNr': 14,
#   'key': 'XAWEXCEYBREZBQHOSPHQGPAX',
#   'imageId': 49050380,
#   'url': 'https://files.transkribus.eu/Get?id=XAWEXCEYBREZBQHOSPHQGPAX&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XAWEXCEYBREZBQHOSPHQGPAX&fileType=thumb',
#   'md5Sum': '4a84bafe7bcd4ad264f3055726f4454f',
#   'fileSize': 941415,
#   'imgFileName': 'p014.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_14 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163192,
#      'parentTsId': 137936888,
#      'key': 'KHAVPRKBZNTJUMQCRPXZYXYC',
#      'pageId': 60726603,
#      'docId': 1620944,
#      'pageNr': 14,
#      'url': 'https://files.transkribus.eu/Get?id=KHAVPRKBZNTJUMQCRPXZYXYC',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286040652,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'e9453c64092595515c21d2ffefa49de9',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 217,
#      'nrOfWords': 217,
#      'nrOfTranscribedWords': 217,
#      'nrOfCharsInLines': 1237,
#      'fileSize': 81324,
#      'fileName': 'p014.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:10.064+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:20.827+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.043+02:00'},
#  {'pageId': 60726604,
#   'docId': 1620944,
#   'pageNr': 15,
#   'key': 'TQNURNXOYOVBFPFSLPOWEHCV',
#   'imageId': 49050381,
#   'url': 'https://files.transkribus.eu/Get?id=TQNURNXOYOVBFPFSLPOWEHCV&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=TQNURNXOYOVBFPFSLPOWEHCV&fileType=thumb',
#   'md5Sum': '33e8d333167be57cf61ad381b1de82ea',
#   'fileSize': 836774,
#   'imgFileName': 'p015.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_15 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163193,
#      'parentTsId': 137936889,
#      'key': 'XLFOXBOLZZFSRRRVTNDWEIEQ',
#      'pageId': 60726604,
#      'docId': 1620944,
#      'pageNr': 15,
#      'url': 'https://files.transkribus.eu/Get?id=XLFOXBOLZZFSRRRVTNDWEIEQ',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286040840,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '4b07d9c2dbbe4ee869d39c46b633b712',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 31,
#      'nrOfTranscribedLines': 31,
#      'nrOfWordsInLines': 206,
#      'nrOfWords': 206,
#      'nrOfTranscribedWords': 206,
#      'nrOfCharsInLines': 1184,
#      'fileSize': 78554,
#      'fileName': 'p015.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:10.447+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:21.044+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.707+02:00'},
#  {'pageId': 60726605,
#   'docId': 1620944,
#   'pageNr': 16,
#   'key': 'NXGAHCJEOZEUYSIXJKHOHNOE',
#   'imageId': 49050382,
#   'url': 'https://files.transkribus.eu/Get?id=NXGAHCJEOZEUYSIXJKHOHNOE&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=NXGAHCJEOZEUYSIXJKHOHNOE&fileType=thumb',
#   'md5Sum': '0604dd5c7958f27357a1b8b6309a8eb3',
#   'fileSize': 995383,
#   'imgFileName': 'p016.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_16 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163194,
#      'parentTsId': 137936890,
#      'key': 'ULKVXTVLIIYUARFIKNJAVCGP',
#      'pageId': 60726605,
#      'docId': 1620944,
#      'pageNr': 16,
#      'url': 'https://files.transkribus.eu/Get?id=ULKVXTVLIIYUARFIKNJAVCGP',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286041057,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '123a8aa4967e83e13753c01b235df03f',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 31,
#      'nrOfTranscribedLines': 31,
#      'nrOfWordsInLines': 215,
#      'nrOfWords': 215,
#      'nrOfTranscribedWords': 215,
#      'nrOfCharsInLines': 1206,
#      'fileSize': 81240,
#      'fileName': 'p016.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:10.869+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:21.306+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.765+02:00'},
#  {'pageId': 60726606,
#   'docId': 1620944,
#   'pageNr': 17,
#   'key': 'KYGCXDSDSIWFAWOVKLFJXRWE',
#   'imageId': 49050383,
#   'url': 'https://files.transkribus.eu/Get?id=KYGCXDSDSIWFAWOVKLFJXRWE&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=KYGCXDSDSIWFAWOVKLFJXRWE&fileType=thumb',
#   'md5Sum': '8f3d1e5a81e181ec9b8d9791a487537d',
#   'fileSize': 916547,
#   'imgFileName': 'p017.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163195,
#      'parentTsId': 137936891,
#      'key': 'VOTPBZCIVVMSMRUTIQUDERQT',
#      'pageId': 60726606,
#      'docId': 1620944,
#      'pageNr': 17,
#      'url': 'https://files.transkribus.eu/Get?id=VOTPBZCIVVMSMRUTIQUDERQT',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286041320,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'd5e15a8721b7f9204b11acd3d4291b95',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 31,
#      'nrOfTranscribedLines': 31,
#      'nrOfWordsInLines': 220,
#      'nrOfWords': 220,
#      'nrOfTranscribedWords': 220,
#      'nrOfCharsInLines': 1228,
#      'fileSize': 82703,
#      'fileName': 'p017.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:11.256+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:21.539+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.758+02:00'},
#  {'pageId': 60726607,
#   'docId': 1620944,
#   'pageNr': 18,
#   'key': 'OYVMAGOQAENDKMPBAIHFRIIJ',
#   'imageId': 49050384,
#   'url': 'https://files.transkribus.eu/Get?id=OYVMAGOQAENDKMPBAIHFRIIJ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=OYVMAGOQAENDKMPBAIHFRIIJ&fileType=thumb',
#   'md5Sum': '52b4bc914e6ae5bfcd7d1ceb2f9fc841',
#   'fileSize': 859395,
#   'imgFileName': 'p018.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163196,
#      'parentTsId': 137936892,
#      'key': 'QHHWMPZBBBKUXQFUGOYCLHZZ',
#      'pageId': 60726607,
#      'docId': 1620944,
#      'pageNr': 18,
#      'url': 'https://files.transkribus.eu/Get?id=QHHWMPZBBBKUXQFUGOYCLHZZ',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286041550,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '3e47b9b1e76760450a5f152f6d38a43c',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 27,
#      'nrOfTranscribedLines': 27,
#      'nrOfWordsInLines': 165,
#      'nrOfWords': 165,
#      'nrOfTranscribedWords': 165,
#      'nrOfCharsInLines': 913,
#      'fileSize': 64814,
#      'fileName': 'p018.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:11.65+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:21.751+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.097+02:00'},
#  {'pageId': 60726608,
#   'docId': 1620944,
#   'pageNr': 19,
#   'key': 'ODCZBSIJMUJLDSWVOJTVNIRD',
#   'imageId': 49050385,
#   'url': 'https://files.transkribus.eu/Get?id=ODCZBSIJMUJLDSWVOJTVNIRD&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=ODCZBSIJMUJLDSWVOJTVNIRD&fileType=thumb',
#   'md5Sum': '12abc4084b82b9765717bd6e185cde89',
#   'fileSize': 892838,
#   'imgFileName': 'p019.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163197,
#      'parentTsId': 137766277,
#      'key': 'FWEFAPEADADDMFQNGLSNEQVP',
#      'pageId': 60726608,
#      'docId': 1620944,
#      'pageNr': 19,
#      'url': 'https://files.transkribus.eu/Get?id=FWEFAPEADADDMFQNGLSNEQVP',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286041764,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '544f427a645d852c8ef992cf3ce42b9a',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 211,
#      'nrOfWords': 211,
#      'nrOfTranscribedWords': 211,
#      'nrOfCharsInLines': 1135,
#      'fileSize': 80032,
#      'fileName': 'p019.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:12.033+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:22.09+02:00',
#   'lastIndexed': '2023-10-26T04:07:24.771+02:00'},
#  {'pageId': 60726609,
#   'docId': 1620944,
#   'pageNr': 20,
#   'key': 'XXKDBEPHUSOJIOFYCFDJXIRX',
#   'imageId': 49050386,
#   'url': 'https://files.transkribus.eu/Get?id=XXKDBEPHUSOJIOFYCFDJXIRX&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XXKDBEPHUSOJIOFYCFDJXIRX&fileType=thumb',
#   'md5Sum': '321c2768a9c9dc87d127958eef427da2',
#   'fileSize': 963505,
#   'imgFileName': 'p020.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163198,
#      'parentTsId': 137766278,
#      'key': 'ELJXMDXQKULAMTMJUEYHNUYP',
#      'pageId': 60726609,
#      'docId': 1620944,
#      'pageNr': 20,
#      'url': 'https://files.transkribus.eu/Get?id=ELJXMDXQKULAMTMJUEYHNUYP',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286042103,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '76884faf4b6301ddc94a634bd197af45',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 205,
#      'nrOfWords': 205,
#      'nrOfTranscribedWords': 205,
#      'nrOfCharsInLines': 1094,
#      'fileSize': 78593,
#      'fileName': 'p020.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:12.436+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:22.557+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.277+02:00'},
#  {'pageId': 60726610,
#   'docId': 1620944,
#   'pageNr': 21,
#   'key': 'RWUTFGXYOYIKWMTGFMNCCSAN',
#   'imageId': 49050387,
#   'url': 'https://files.transkribus.eu/Get?id=RWUTFGXYOYIKWMTGFMNCCSAN&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=RWUTFGXYOYIKWMTGFMNCCSAN&fileType=thumb',
#   'md5Sum': '856e16777fafba3b8e442f453195a526',
#   'fileSize': 884395,
#   'imgFileName': 'p021.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163199,
#      'parentTsId': 137766279,
#      'key': 'UVETEOPBMHXFVEIMAJIOEUTT',
#      'pageId': 60726610,
#      'docId': 1620944,
#      'pageNr': 21,
#      'url': 'https://files.transkribus.eu/Get?id=UVETEOPBMHXFVEIMAJIOEUTT',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286042570,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': 'dcfb3ba6e33d0892bd665ec949d528c0',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 216,
#      'nrOfWords': 216,
#      'nrOfTranscribedWords': 216,
#      'nrOfCharsInLines': 1179,
#      'fileSize': 81562,
#      'fileName': 'p021.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:12.951+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:22.938+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.05+02:00'},
#  {'pageId': 60726611,
#   'docId': 1620944,
#   'pageNr': 22,
#   'key': 'YEJRVKBHGHNGTOEQJIDKGLXF',
#   'imageId': 49050388,
#   'url': 'https://files.transkribus.eu/Get?id=YEJRVKBHGHNGTOEQJIDKGLXF&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=YEJRVKBHGHNGTOEQJIDKGLXF&fileType=thumb',
#   'md5Sum': '93dde91b9e33e9e37af6dcc2cd088a2f',
#   'fileSize': 930450,
#   'imgFileName': 'p022.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163200,
#      'parentTsId': 137766280,
#      'key': 'HNESEGIXOYGAJIOSQSDKJZAI',
#      'pageId': 60726611,
#      'docId': 1620944,
#      'pageNr': 22,
#      'url': 'https://files.transkribus.eu/Get?id=HNESEGIXOYGAJIOSQSDKJZAI',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286042951,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '7bd0131fbe6b450a038c867f5d733fa8',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 31,
#      'nrOfTranscribedLines': 31,
#      'nrOfWordsInLines': 216,
#      'nrOfWords': 216,
#      'nrOfTranscribedWords': 216,
#      'nrOfCharsInLines': 1215,
#      'fileSize': 81772,
#      'fileName': 'p022.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:13.773+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:23.201+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.037+02:00'},
#  {'pageId': 60726612,
#   'docId': 1620944,
#   'pageNr': 23,
#   'key': 'EJWVLRKXPEJANRAZDVXYRJGS',
#   'imageId': 49050389,
#   'url': 'https://files.transkribus.eu/Get?id=EJWVLRKXPEJANRAZDVXYRJGS&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=EJWVLRKXPEJANRAZDVXYRJGS&fileType=thumb',
#   'md5Sum': '9b55efb14e17b2047a25e71752d7eaa8',
#   'fileSize': 844269,
#   'imgFileName': 'p023.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_23 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163201,
#      'parentTsId': 137766281,
#      'key': 'DHQQXRPKGCLPTLIQYWZYSOTP',
#      'pageId': 60726612,
#      'docId': 1620944,
#      'pageNr': 23,
#      'url': 'https://files.transkribus.eu/Get?id=DHQQXRPKGCLPTLIQYWZYSOTP',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286043214,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '32abb22f40f4bb9594527a8debc4ec21',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 174,
#      'nrOfWords': 174,
#      'nrOfTranscribedWords': 174,
#      'nrOfCharsInLines': 1021,
#      'fileSize': 68908,
#      'fileName': 'p023.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:14.387+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:23.424+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.273+02:00'},
#  {'pageId': 60726613,
#   'docId': 1620944,
#   'pageNr': 24,
#   'key': 'GRXQSTOAIRYARFCJXTJYRTGJ',
#   'imageId': 49050390,
#   'url': 'https://files.transkribus.eu/Get?id=GRXQSTOAIRYARFCJXTJYRTGJ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=GRXQSTOAIRYARFCJXTJYRTGJ&fileType=thumb',
#   'md5Sum': '4addc29fa1549320b196b49b51f79eb6',
#   'fileSize': 882306,
#   'imgFileName': 'p024.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_24 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163202,
#      'parentTsId': 137766283,
#      'key': 'CBWPFDSVKGYHAEDDSCNTXQRA',
#      'pageId': 60726613,
#      'docId': 1620944,
#      'pageNr': 24,
#      'url': 'https://files.transkribus.eu/Get?id=CBWPFDSVKGYHAEDDSCNTXQRA',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286043437,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '6af31e8a55f457cf0af1c4ca6a098153',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 30,
#      'nrOfTranscribedLines': 30,
#      'nrOfWordsInLines': 200,
#      'nrOfWords': 200,
#      'nrOfTranscribedWords': 200,
#      'nrOfCharsInLines': 1127,
#      'fileSize': 76828,
#      'fileName': 'p024.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:14.852+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:23.647+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.294+02:00'},
#  {'pageId': 60726615,
#   'docId': 1620944,
#   'pageNr': 25,
#   'key': 'OCMDSZJLSGFHZBDZKCHPQMJN',
#   'imageId': 49050391,
#   'url': 'https://files.transkribus.eu/Get?id=OCMDSZJLSGFHZBDZKCHPQMJN&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=OCMDSZJLSGFHZBDZKCHPQMJN&fileType=thumb',
#   'md5Sum': 'f000cc8d1ea73e911a0f04016a012e31',
#   'fileSize': 821089,
#   'imgFileName': 'p025.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_25 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163203,
#      'parentTsId': 137766284,
#      'key': 'EBABUFDJKLVODJSNABRRKXOQ',
#      'pageId': 60726615,
#      'docId': 1620944,
#      'pageNr': 25,
#      'url': 'https://files.transkribus.eu/Get?id=EBABUFDJKLVODJSNABRRKXOQ',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286043659,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '01e1874093edebf122e3997517d0d5ac',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 28,
#      'nrOfTranscribedLines': 28,
#      'nrOfWordsInLines': 166,
#      'nrOfWords': 166,
#      'nrOfTranscribedWords': 166,
#      'nrOfCharsInLines': 928,
#      'fileSize': 65640,
#      'fileName': 'p025.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:15.211+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:23.89+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.016+02:00'},
#  {'pageId': 60726616,
#   'docId': 1620944,
#   'pageNr': 26,
#   'key': 'IBHCZLDEKQLLFYVGQIXLCPSF',
#   'imageId': 49050392,
#   'url': 'https://files.transkribus.eu/Get?id=IBHCZLDEKQLLFYVGQIXLCPSF&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=IBHCZLDEKQLLFYVGQIXLCPSF&fileType=thumb',
#   'md5Sum': '9d7554595439eea687e39fc99b974075',
#   'fileSize': 881368,
#   'imgFileName': 'p026.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163204,
#      'parentTsId': 137766286,
#      'key': 'CVVSSAHZPEHSMPPTIGNGDLCZ',
#      'pageId': 60726616,
#      'docId': 1620944,
#      'pageNr': 26,
#      'url': 'https://files.transkribus.eu/Get?id=CVVSSAHZPEHSMPPTIGNGDLCZ',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286043904,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '4f58d64e5e79a99ee123f7ac6e3b2b60',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 29,
#      'nrOfTranscribedLines': 29,
#      'nrOfWordsInLines': 177,
#      'nrOfWords': 177,
#      'nrOfTranscribedWords': 177,
#      'nrOfCharsInLines': 1040,
#      'fileSize': 69340,
#      'fileName': 'p026.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:15.653+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:24.806+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.285+02:00'},
#  {'pageId': 60726617,
#   'docId': 1620944,
#   'pageNr': 27,
#   'key': 'NERFAADMYVRVXFHZCYBMISQW',
#   'imageId': 49050393,
#   'url': 'https://files.transkribus.eu/Get?id=NERFAADMYVRVXFHZCYBMISQW&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=NERFAADMYVRVXFHZCYBMISQW&fileType=thumb',
#   'md5Sum': 'f6d882894ed557a7ec2c38427a616046',
#   'fileSize': 784700,
#   'imgFileName': 'p027.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163205,
#      'parentTsId': 137766287,
#      'key': 'PNVVBDINFJYMOBBFREKHVBBI',
#      'pageId': 60726617,
#      'docId': 1620944,
#      'pageNr': 27,
#      'url': 'https://files.transkribus.eu/Get?id=PNVVBDINFJYMOBBFREKHVBBI',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286044818,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '839200458fdedef63045c64368c57582',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 28,
#      'nrOfTranscribedLines': 28,
#      'nrOfWordsInLines': 158,
#      'nrOfWords': 158,
#      'nrOfTranscribedWords': 158,
#      'nrOfCharsInLines': 962,
#      'fileSize': 63889,
#      'fileName': 'p027.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:16.117+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:25.108+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.308+02:00'},
#  {'pageId': 60726618,
#   'docId': 1620944,
#   'pageNr': 28,
#   'key': 'VAZKBUFYAQSYGOOPUOFXQIJN',
#   'imageId': 49050394,
#   'url': 'https://files.transkribus.eu/Get?id=VAZKBUFYAQSYGOOPUOFXQIJN&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=VAZKBUFYAQSYGOOPUOFXQIJN&fileType=thumb',
#   'md5Sum': '157a595a9ee58ac709f258db3828e7cf',
#   'fileSize': 835221,
#   'imgFileName': 'p028.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163206,
#      'parentTsId': 137766288,
#      'key': 'HLBAPNXRIRXLYSNFXNFLJPDB',
#      'pageId': 60726618,
#      'docId': 1620944,
#      'pageNr': 28,
#      'url': 'https://files.transkribus.eu/Get?id=HLBAPNXRIRXLYSNFXNFLJPDB',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286045119,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '0dd39c9dc1732778b1477971f78ca39e',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 25,
#      'nrOfTranscribedLines': 25,
#      'nrOfWordsInLines': 134,
#      'nrOfWords': 134,
#      'nrOfTranscribedWords': 134,
#      'nrOfCharsInLines': 828,
#      'fileSize': 54926,
#      'fileName': 'p028.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:16.481+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:25.328+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.264+02:00'},
#  {'pageId': 60726619,
#   'docId': 1620944,
#   'pageNr': 29,
#   'key': 'SMIMAUEOSISAZAKHGHSRLPAD',
#   'imageId': 49050395,
#   'url': 'https://files.transkribus.eu/Get?id=SMIMAUEOSISAZAKHGHSRLPAD&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=SMIMAUEOSISAZAKHGHSRLPAD&fileType=thumb',
#   'md5Sum': '805a029b562d725735c5f7601842b95c',
#   'fileSize': 764048,
#   'imgFileName': 'p029.jpg',
#   'indexProblem': 'Error from server at https://read-vm01.uibk.ac.at:8983/solr: Exception writing document id 1620944_29 to the index; possible analysis error.',
#   'tsList': {'transcripts': [{'tsId': 138163207,
#      'parentTsId': 137766289,
#      'key': 'STFKIZEJJUZXRSIBQYVDYRXR',
#      'pageId': 60726619,
#      'docId': 1620944,
#      'pageNr': 29,
#      'url': 'https://files.transkribus.eu/Get?id=STFKIZEJJUZXRSIBQYVDYRXR',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286045389,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '801ce423c66221c46b55962b79133822',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 27,
#      'nrOfTranscribedLines': 27,
#      'nrOfWordsInLines': 152,
#      'nrOfWords': 152,
#      'nrOfTranscribedWords': 152,
#      'nrOfCharsInLines': 836,
#      'fileSize': 61046,
#      'fileName': 'p029.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:17.112+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:25.568+02:00',
#   'lastIndexed': '2023-10-26T04:07:29.294+02:00'},
#  {'pageId': 60726620,
#   'docId': 1620944,
#   'pageNr': 30,
#   'key': 'XWSEAEMXANVGZOACKMYMBYRE',
#   'imageId': 49050396,
#   'url': 'https://files.transkribus.eu/Get?id=XWSEAEMXANVGZOACKMYMBYRE&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XWSEAEMXANVGZOACKMYMBYRE&fileType=thumb',
#   'md5Sum': '41ca2cfe6e9146afa521f39bdd52ab8c',
#   'fileSize': 809709,
#   'imgFileName': 'p030.jpg',
#   'tsList': {'transcripts': [{'tsId': 138163208,
#      'parentTsId': 137766290,
#      'key': 'CALEEKHCJMPRKDREFKRPQWBJ',
#      'pageId': 60726620,
#      'docId': 1620944,
#      'pageNr': 30,
#      'url': 'https://files.transkribus.eu/Get?id=CALEEKHCJMPRKDREFKRPQWBJ',
#      'status': 'IN_PROGRESS',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1698286045581,
#      'toolName': 'PyLaia decoding 2.6.0 - Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'jobId': 6709587,
#      'note': 'Model: 49007, NZZ Gold Standard M1+, LM: none',
#      'md5Sum': '5d0512bdf79725e76b887b766ee2f4a3',
#      'nrOfRegions': 1,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 28,
#      'nrOfTranscribedLines': 28,
#      'nrOfWordsInLines': 162,
#      'nrOfWords': 162,
#      'nrOfTranscribedWords': 162,
#      'nrOfCharsInLines': 909,
#      'fileSize': 64951,
#      'fileName': 'p030.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:43:17.614+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastModified': '2023-10-26T04:07:25.953+02:00',
#   'lastIndexed': '2023-10-26T04:07:28.96+02:00'},
#  {'pageId': 60726621,
#   'docId': 1620944,
#   'pageNr': 31,
#   'key': 'FPNRZMCUJABVOFPGFYRADXBT',
#   'imageId': 49050397,
#   'url': 'https://files.transkribus.eu/Get?id=FPNRZMCUJABVOFPGFYRADXBT&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=FPNRZMCUJABVOFPGFYRADXBT&fileType=thumb',
# ...
#   'lastIndexed': '2023-10-20T15:44:20.593+02:00'},
#  {'pageId': 60726726,
#   'docId': 1620944,
#   'pageNr': 135,
#   'key': 'WRUBIQLMUXGPSQSUPOWECYSQ',
#   'imageId': 49050502,
#   'url': 'https://files.transkribus.eu/Get?id=WRUBIQLMUXGPSQSUPOWECYSQ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=WRUBIQLMUXGPSQSUPOWECYSQ&fileType=thumb',
#   'md5Sum': '51dc98f07220f24e4ff04203fa497ef3',
#   'fileSize': 682916,
#   'imgFileName': 'p135.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766406,
#      'parentTsId': -1,
#      'key': 'JSWDJTSRVOSTYKVFABPNBNZB',
#      'pageId': 60726726,
#      'docId': 1620944,
#      'pageNr': 135,
#      'url': 'https://files.transkribus.eu/Get?id=JSWDJTSRVOSTYKVFABPNBNZB',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'cf2a283f631822389c1d28ff46966120',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p135.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:07.19+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:19.939+02:00'},
#  {'pageId': 60726727,
#   'docId': 1620944,
#   'pageNr': 136,
#   'key': 'HOHAVJSUCNDKMEPTMQGVIXVK',
#   'imageId': 49050503,
#   'url': 'https://files.transkribus.eu/Get?id=HOHAVJSUCNDKMEPTMQGVIXVK&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=HOHAVJSUCNDKMEPTMQGVIXVK&fileType=thumb',
#   'md5Sum': '3d59b9a745b03d4fd3b32731684e8abe',
#   'fileSize': 757080,
#   'imgFileName': 'p136.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766407,
#      'parentTsId': -1,
#      'key': 'SANTYTMTQPMIXMLSCTPXQWUW',
#      'pageId': 60726727,
#      'docId': 1620944,
#      'pageNr': 136,
#      'url': 'https://files.transkribus.eu/Get?id=SANTYTMTQPMIXMLSCTPXQWUW',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'fdebd6405d24a28b9a0fa82898281fba',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p136.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:07.537+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.027+02:00'},
#  {'pageId': 60726728,
#   'docId': 1620944,
#   'pageNr': 137,
#   'key': 'WFMFHLQJKHQHMRGDBWHFDKPU',
#   'imageId': 49050504,
#   'url': 'https://files.transkribus.eu/Get?id=WFMFHLQJKHQHMRGDBWHFDKPU&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=WFMFHLQJKHQHMRGDBWHFDKPU&fileType=thumb',
#   'md5Sum': 'd06092e2c91536385b0c661cffcc8c98',
#   'fileSize': 210720,
#   'imgFileName': 'p137.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766408,
#      'parentTsId': -1,
#      'key': 'FLHIKWRGYDDWRDMVQBZLGEFR',
#      'pageId': 60726728,
#      'docId': 1620944,
#      'pageNr': 137,
#      'url': 'https://files.transkribus.eu/Get?id=FLHIKWRGYDDWRDMVQBZLGEFR',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '46896a01a1e33776e8b42df80d7d300f',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p137.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:07.98+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.099+02:00'},
#  {'pageId': 60726729,
#   'docId': 1620944,
#   'pageNr': 138,
#   'key': 'CVRIKVJJPMUCXXMWDQYHCJFI',
#   'imageId': 49050505,
#   'url': 'https://files.transkribus.eu/Get?id=CVRIKVJJPMUCXXMWDQYHCJFI&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=CVRIKVJJPMUCXXMWDQYHCJFI&fileType=thumb',
#   'md5Sum': '77067a21f2578f2baa624d12001017f2',
#   'fileSize': 721791,
#   'imgFileName': 'p138.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766409,
#      'parentTsId': -1,
#      'key': 'LASREXMRKMHPFKGKAFEKVYIT',
#      'pageId': 60726729,
#      'docId': 1620944,
#      'pageNr': 138,
#      'url': 'https://files.transkribus.eu/Get?id=LASREXMRKMHPFKGKAFEKVYIT',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '23f5f4db0013a26d2923f2f35c4e7065',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p138.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:08.341+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.221+02:00'},
#  {'pageId': 60726730,
#   'docId': 1620944,
#   'pageNr': 139,
#   'key': 'UEVAMDNEQAKXPIPHORABWLZC',
#   'imageId': 49050506,
#   'url': 'https://files.transkribus.eu/Get?id=UEVAMDNEQAKXPIPHORABWLZC&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=UEVAMDNEQAKXPIPHORABWLZC&fileType=thumb',
#   'md5Sum': '7a1c3cd9bad6a98160cb3c305f83e2be',
#   'fileSize': 1520927,
#   'imgFileName': 'p139.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766410,
#      'parentTsId': -1,
#      'key': 'RXOISZROXHRRFUXDOSSNJJHY',
#      'pageId': 60726730,
#      'docId': 1620944,
#      'pageNr': 139,
#      'url': 'https://files.transkribus.eu/Get?id=RXOISZROXHRRFUXDOSSNJJHY',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '0775700d00ebb278a279bd9ed4201700',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p139.xml'}]},
#   'width': 3508,
#   'height': 2479,
#   'created': '2023-10-20T15:44:08.698+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.327+02:00'},
#  {'pageId': 60726731,
#   'docId': 1620944,
#   'pageNr': 140,
#   'key': 'MQQNGZISAMQEDVIRURQYLGMY',
#   'imageId': 49050507,
#   'url': 'https://files.transkribus.eu/Get?id=MQQNGZISAMQEDVIRURQYLGMY&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=MQQNGZISAMQEDVIRURQYLGMY&fileType=thumb',
#   'md5Sum': '1abf90b35d90d0aa4ec881447760e5b4',
#   'fileSize': 564680,
#   'imgFileName': 'p140.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766411,
#      'parentTsId': -1,
#      'key': 'UWMPPDARIJPMFURLMNKYJMSX',
#      'pageId': 60726731,
#      'docId': 1620944,
#      'pageNr': 140,
#      'url': 'https://files.transkribus.eu/Get?id=UWMPPDARIJPMFURLMNKYJMSX',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '4ce32f3c74f9376dcc35a118d69c01b9',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p140.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:09.057+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.236+02:00'},
#  {'pageId': 60726732,
#   'docId': 1620944,
#   'pageNr': 141,
#   'key': 'XVIGFHFPTFBRIONCIRQNTVDG',
#   'imageId': 49050508,
#   'url': 'https://files.transkribus.eu/Get?id=XVIGFHFPTFBRIONCIRQNTVDG&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XVIGFHFPTFBRIONCIRQNTVDG&fileType=thumb',
#   'md5Sum': '53093575078b25939c27dabb900d4623',
#   'fileSize': 427097,
#   'imgFileName': 'p141.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766412,
#      'parentTsId': -1,
#      'key': 'JVOLNNYVMKHGUOHQLXVFZJVH',
#      'pageId': 60726732,
#      'docId': 1620944,
#      'pageNr': 141,
#      'url': 'https://files.transkribus.eu/Get?id=JVOLNNYVMKHGUOHQLXVFZJVH',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'a98b79521c72254c8c3fb4fa7f13eb94',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p141.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:09.481+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.342+02:00'},
#  {'pageId': 60726733,
#   'docId': 1620944,
#   'pageNr': 142,
#   'key': 'TXLHAHWEDLOINOJFWOQFEMTQ',
#   'imageId': 49050509,
#   'url': 'https://files.transkribus.eu/Get?id=TXLHAHWEDLOINOJFWOQFEMTQ&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=TXLHAHWEDLOINOJFWOQFEMTQ&fileType=thumb',
#   'md5Sum': '2d87ce715a30bd4a0337b54cd4af4b78',
#   'fileSize': 487439,
#   'imgFileName': 'p142.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766414,
#      'parentTsId': -1,
#      'key': 'FDTVPCPRDFLFRLJFSAVHAAMR',
#      'pageId': 60726733,
#      'docId': 1620944,
#      'pageNr': 142,
#      'url': 'https://files.transkribus.eu/Get?id=FDTVPCPRDFLFRLJFSAVHAAMR',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'f2474e5cfebe7e669c5a6b44a0014452',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p142.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:09.894+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.417+02:00'},
#  {'pageId': 60726734,
#   'docId': 1620944,
#   'pageNr': 143,
#   'key': 'OERYHISCCXSRFOYDBLKJTSUO',
#   'imageId': 49050510,
#   'url': 'https://files.transkribus.eu/Get?id=OERYHISCCXSRFOYDBLKJTSUO&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=OERYHISCCXSRFOYDBLKJTSUO&fileType=thumb',
#   'md5Sum': '69b25ab88e1982c46dc8915bdd6b327c',
#   'fileSize': 512382,
#   'imgFileName': 'p143.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766415,
#      'parentTsId': -1,
#      'key': 'URILXVYMYOGXTWDHXOLWYTYW',
#      'pageId': 60726734,
#      'docId': 1620944,
#      'pageNr': 143,
#      'url': 'https://files.transkribus.eu/Get?id=URILXVYMYOGXTWDHXOLWYTYW',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'b95995c0c5108954bba4fa8eaeaf6002',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p143.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:10.554+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.509+02:00'},
#  {'pageId': 60726735,
#   'docId': 1620944,
#   'pageNr': 144,
#   'key': 'RXQVNTFSZFBGGZSBPKLXRUQR',
#   'imageId': 49050511,
#   'url': 'https://files.transkribus.eu/Get?id=RXQVNTFSZFBGGZSBPKLXRUQR&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=RXQVNTFSZFBGGZSBPKLXRUQR&fileType=thumb',
#   'md5Sum': '775fc2eda9b7d1aa9972e215752afc51',
#   'fileSize': 484804,
#   'imgFileName': 'p144.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766416,
#      'parentTsId': -1,
#      'key': 'FEQAMYTJXIJAPYMTRFJUYDPG',
#      'pageId': 60726735,
#      'docId': 1620944,
#      'pageNr': 144,
#      'url': 'https://files.transkribus.eu/Get?id=FEQAMYTJXIJAPYMTRFJUYDPG',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '2338b6fd0ef2828b6082ecb16ae33f40',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p144.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:10.892+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:19.946+02:00'},
#  {'pageId': 60726736,
#   'docId': 1620944,
#   'pageNr': 145,
#   'key': 'UIAXGLUAOXNOQVIWJDIDYYKW',
#   'imageId': 49050512,
#   'url': 'https://files.transkribus.eu/Get?id=UIAXGLUAOXNOQVIWJDIDYYKW&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=UIAXGLUAOXNOQVIWJDIDYYKW&fileType=thumb',
#   'md5Sum': '159adfb6c68af09cf5d98b8f4a4f49ba',
#   'fileSize': 517751,
#   'imgFileName': 'p145.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766417,
#      'parentTsId': -1,
#      'key': 'SJGDDMDJQIDLEKIAXZMJLBWT',
#      'pageId': 60726736,
#      'docId': 1620944,
#      'pageNr': 145,
#      'url': 'https://files.transkribus.eu/Get?id=SJGDDMDJQIDLEKIAXZMJLBWT',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': '3f13760b9922a5256cb3fc70497e72e3',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p145.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:11.636+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.018+02:00'},
#  {'pageId': 60726737,
#   'docId': 1620944,
#   'pageNr': 146,
#   'key': 'XEBXJKADRSTNUQYLKFWCBJSL',
#   'imageId': 49050513,
#   'url': 'https://files.transkribus.eu/Get?id=XEBXJKADRSTNUQYLKFWCBJSL&fileType=view',
#   'thumbUrl': 'https://files.transkribus.eu/Get?id=XEBXJKADRSTNUQYLKFWCBJSL&fileType=thumb',
#   'md5Sum': '3036be8488b5c6ab0fd5efa2b7ae4865',
#   'fileSize': 591205,
#   'imgFileName': 'p146.jpg',
#   'tsList': {'transcripts': [{'tsId': 137766419,
#      'parentTsId': -1,
#      'key': 'NQXAGNDNEZUXPMAWEMXKMASF',
#      'pageId': 60726737,
#      'docId': 1620944,
#      'pageNr': 146,
#      'url': 'https://files.transkribus.eu/Get?id=NQXAGNDNEZUXPMAWEMXKMASF',
#      'status': 'NEW',
#      'userName': 'a12110417@unet.univie.ac.at',
#      'userId': 192043,
#      'timestamp': 1697809383282,
#      'md5Sum': 'f7953d9db1a41ba38915e30147c79285',
#      'nrOfRegions': 0,
#      'nrOfTranscribedRegions': 0,
#      'nrOfWordsInRegions': 0,
#      'nrOfLines': 0,
#      'nrOfTranscribedLines': 0,
#      'nrOfWordsInLines': 0,
#      'nrOfWords': 0,
#      'nrOfTranscribedWords': 0,
#      'nrOfCharsInLines': 0,
#      'fileSize': 610,
#      'fileName': 'p146.xml'}]},
#   'width': 2479,
#   'height': 3508,
#   'created': '2023-10-20T15:44:11.998+02:00',
#   'indexed': True,
#   'imageVersions': {'imageVersions': []},
#   'lastIndexed': '2023-10-20T15:44:20.067+02:00'}]

# %%
#pageNr = 8
#doc = client.get_page_xml(colId, DocId, pageNr)

# %%
def check_page(page_xml):
    """ Make sure that the page_xml contains
        – TextRegions
        – Baselines
        – TextEquiv, i.e. actual text in the lines. 
        This is useful for further processing of the data to prevent crashes.
        
        page_xml -- a lxml.objectify object of a page in Transkribus """
        
    ns = "{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}"
    
    if page_xml.find(f".//{ns}TextRegion") is None:
        return "PAGE-XML: ERROR: No TextRegions found."
    if page_xml.find(f".//{ns}Baseline") is None:
        return "PAGE-XML: ERROR: No BaseLines found."
    if page_xml.find(f".//{ns}TextEquiv") is None:
        return "PAGE-XML: ERROR: Lines contain no text."

    return True

#check_page(doc)
# Out:
# True

# %%
#doc.Page.TextRegion[0].TextLine[3].TextEquiv.Unicode
# Out:
# 'Wenn es für jeden Reisenden unerläßlich ist, sich'

# %%
#import re

#def get_custom_attributes(string):
    #custom_attributes = re.compile(r'\{(\w*?):(\w*?);\}')
    #return dict(custom_attributes.findall(string))

# %%
# Store the namespace string used by the Transkribus page_xml format:
#ns = "{http://schema.primaresearch.org/PAGE/gts/pagecontent/2013-07-15}"

#for line in doc.Page.iter(f"{ns}TextLine"): # Cf. the section "tree iteration" in https://lxml.de/tutorial.html
    # Get the attributes of the TextRegion:
    #custom_attributes = get_custom_attributes(line.getparent().attrib['custom'])
    #regionNr = custom_attributes_region['index']
    
    # In the following line you could filter TextRegions tagged with a specific tag (like "paragraph"):
    #if custom_attributes.get("type"): # No filtering at the moment.
    #print(line.attrib['id'], line.TextEquiv.Unicode)
# Out:
# tr_1_tl_1 I. Wegweiser.
# tr_1_tl_2 Orientirung in Wien.
# tr_1_tl_3 Rundgang um die Bastei.
# tr_1_tl_4 Wenn es für jeden Reisenden unerläßlich ist, sich
# tr_1_tl_5 in einer fremden Stadt zu orientiren, so ist es we¬
# tr_1_tl_6 nigstens in Wien sehr leicht. Der Stephansplatz
# tr_1_tl_7 legt so ziemlich mitten in der Stadt, und mit Hilfe
# tr_1_tl_8 des Planes wird man bald die Hauptpulsader der
# tr_1_tl_9 innern Stadt kennen lernen; diese führt nämlich vom
# tr_1_tl_10 Burgthor durch die Burg über den Michaels¬
# tr_1_tl_11 platz, Kohlmarkt, Graben, Stephanö¬
# tr_1_tl_12 platz, Bischofs- und Nothenthurmstraße
# tr_1_tl_13 zum Nothenthurmthore, und bildet die Figur
# tr_1_tl_14 einer doppelten
# tr_1_tl_15 — Stufe, deren innerer Winkel
# tr_1_tl_16 St. Stephan ist. Zu einer dieser Straßen, auf
# tr_1_tl_17 einen dieser Plätze wird man sich bald finden oder
# tr_1_tl_18 erfragen. — Eine Besteigung des Stephans¬
# tr_1_tl_19 thurmes gibt wohl eine vollständige Uebersicht der
# tr_1_tl_20 Stadt und Umgebung, aber zur Orientirung ist sie
# tr_1_tl_21 keineswegs so wesentlich

# %%
#page = []

#for line in doc.Page.iter(f"{ns}TextLine"): # Cf. the section "tree iteration" in https://lxml.de/tutorial.html
    # Get the attributes of the TextRegion:
    #custom_attributes = get_custom_attributes(line.getparent().attrib['custom'])
    #lineNr = get_custom_attributes(line.attrib['custom'])['index']
    #raw_data = line.TextEquiv.Unicode
    #for i in lineNr:
        #for x in raw_data:
            #page[i] = x
    
    #new_line = {'Zeile': f"{lineNr}",
                'Text': raw_data}
    #page.append(new_line)

# %%
#print(page)
# Out:
# [{'Zeile': '0', 'Text': 'I. Wegweiser.'}, {'Zeile': '1', 'Text': 'Orientirung in Wien.'}, {'Zeile': '2', 'Text': 'Rundgang um die Bastei.'}, {'Zeile': '3', 'Text': 'Wenn es für jeden Reisenden unerläßlich ist, sich'}, {'Zeile': '4', 'Text': 'in einer fremden Stadt zu orientiren, so ist es we¬'}, {'Zeile': '5', 'Text': 'nigstens in Wien sehr leicht. Der Stephansplatz'}, {'Zeile': '6', 'Text': 'legt so ziemlich mitten in der Stadt, und mit Hilfe'}, {'Zeile': '7', 'Text': 'des Planes wird man bald die Hauptpulsader der'}, {'Zeile': '8', 'Text': 'innern Stadt kennen lernen; diese führt nämlich vom'}, {'Zeile': '9', 'Text': 'Burgthor durch die Burg über den Michaels¬'}, {'Zeile': '10', 'Text': 'platz, Kohlmarkt, Graben, Stephanö¬'}, {'Zeile': '11', 'Text': 'platz, Bischofs- und Nothenthurmstraße'}, {'Zeile': '12', 'Text': 'zum Nothenthurmthore, und bildet die Figur'}, {'Zeile': '13', 'Text': 'einer doppelten'}, {'Zeile': '14', 'Text': '— Stufe, deren innerer Winkel'}, {'Zeile': '15', 'Text': 'St. Stephan ist. Zu einer dieser Straßen, auf'}, {'Zeile': '16', 'Text': 'einen dieser Plätze wird man sich bald finden oder'}, {'Zeile': '17', 'Text': 'erfragen. — Eine Besteigung des Stephans¬'}, {'Zeile': '18', 'Text': 'thurmes gibt wohl eine vollständige Uebersicht der'}, {'Zeile': '19', 'Text': 'Stadt und Umgebung, aber zur Orientirung ist sie'}, {'Zeile': '20', 'Text': 'keineswegs so wesentlich'}]

# %%
#client.update_page_status(240344, 1620944, 8, "IN_PROGRESS")
# Out:
# TRANSKRIBUS: Updated status of page 8 to IN_PROGRESS in collection 240344, document 1620944.
# True

# %%
#client.logout()
# Out:
# TRANSKRIBUS: Logged out successfully.
# True
