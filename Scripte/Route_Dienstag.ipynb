# %% [markdown]
# # Route Dienstag

# %%
from Classes_and_functions import Extractor, structure, matcher, Kulturwiki_comparer, Kulturwiki_indexer, Steinhausen_comparer, Steinhausen_indexer, table_comparer
import difflib as dl
import pandas as pd

from os import path
xml_path = path.relpath("../Data/pages_8_47.xml")

## I used the python-module BeautifulSoup for XML-Parsing.


from bs4 import BeautifulSoup   #import the module
with open(xml_path, encoding='utf8') as file:   #load & parse the whole text and turn it into an BeautifulSoup object for further analysis.
    contents = file.read()
    soup = BeautifulSoup(contents, 'xml')

# %%
Dienstag = Extractor('Dienstag.', 'hi', 'Mittwoch.', 'hi', 'placeName')

# %%
Dienstag.extract_text_and_tags(soup)

# %%
places = Dienstag.tag_list

# %%
clean_places = structure(places)

# %%
#check for consistency

print(clean_places)
print(len(clean_places))
# Out:
# ['Kärnthnerthore', 'große Wienbrücke', 'Karlskirche', 'Martinolli', 'Palais ', 'Schwarzenberg', 'Heugasse', 'Belvedere', 'k. k. Gemäldegallerie', 'Garten für die österreichische Flora', 'Ambraser Sammlung', 'Kabinet äghptischer Alterthümer', 'unteren Belvedere', 'Hauptstraße der Vorstadt ', 'Rennweg', 'Kirche und Kloster der  Salesianerinnen', 'MiIitär=Medikamenten=Regie', 'botanischen Garten. ViIIa Metternich', 'Neustädter Kanal', 'Palais der italienischen Garde', 'Haltergasse', 'Versuchsgarten den Landwirthschaftsgesellschaft', 'Garten der Gartenbaugesellschaft', 'Kanal', 'Thierarznei=Jnstitut', 'Kanonenbohrerei', 'Münzhaus', 'Jnvalidenhause', 'Wienbrücke', 'tubenthor ', 'Stadt London', 'Hauptmauth', 'goldene', 'Ente', 'König von Ungarn', 'Schulenstraße', 'Herrnals', 'Türkenschanze', 'Dornbach', 'Parke des  Fürsten Schwarzenberg', 'Hameau']
# 41

# %%
#manual refinement

print(clean_places.index('botanischen Garten. ViIIa Metternich'))

clean_places.insert(17, 'botanischen Garten.')
clean_places.insert(18, 'ViIIa Metternich')

clean_places.remove('botanischen Garten. ViIIa Metternich')
# Out:
# 17

# %%
import functools
print(clean_places.index('goldene'))
clean_places[33:35] = [functools.reduce(lambda x, y: x + ' ' + y, clean_places[33:35])]
# Out:
# 33

# %%
place_list = matcher(clean_places)

# %%
print(place_list)
# Out:
# ['Kärnthnerthore', 'große Wienbrücke', 'Karlskirche', 'Martinolli', 'Palais ', 'Schwarzenberg', 'Heugasse', 'Belvedere', 'k. k. Gemäldegallerie', 'Garten für die österreichische Flora', 'Ambraser Sammlung', 'Kabinet äghptischer Alterthümer', 'unteren Belvedere', 'Hauptstraße der Vorstadt ', 'Rennweg', 'Kirche und Kloster der  Salesianerinnen', 'MiIitär=Medikamenten=Regie', 'botanischen Garten.', 'ViIIa Metternich', 'Neustädter Kanal', 'Palais der italienischen Garde', 'Haltergasse', 'Versuchsgarten den Landwirthschaftsgesellschaft', 'Garten der Gartenbaugesellschaft', 'Kanal', 'Thierarznei=Jnstitut', 'Kanonenbohrerei', 'Münzhaus', 'Jnvalidenhause', 'Wienbrücke', 'tubenthor ', 'Stadt London', 'Hauptmauth', 'goldene Ente', 'König von Ungarn', 'Schulenstraße', 'Herrnals', 'Türkenschanze', 'Dornbach', 'Parke des  Fürsten Schwarzenberg', 'Hameau']

# %%
coordinates =  Kulturwiki_comparer(place_list)

# %%
#coordinates.head(50)

# %%
coordinates_choice = coordinates.drop(coordinates[coordinates['MATCH_SCORE'] <= 85].index)

# %%
place_coord = Kulturwiki_indexer(coordinates_choice, place_list)

# %%
Steinhausen_coord = Steinhausen_comparer(place_list)
# Out:
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']
# Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '<...>']

# %%
#Steinhausen_coord.head(50)

# %%
Steinhausen_choice = Steinhausen_coord.drop(Steinhausen_coord[Steinhausen_coord['MATCH_SCORE'] <= 87].index)

# %%
place_Sth_coord = Steinhausen_indexer(Steinhausen_choice, place_list)

# %%
place_Sth_coord
# Out:
#                                          NEUE_NAMEN  Longitude   Latitude
# 0                                    Kärnthnerthore        NaN        NaN
# 1                                  große Wienbrücke        NaN        NaN
# 2                                       Karlskirche        NaN        NaN
# 3                                        Martinolli  16.374924  48.209951
# 4                                           Palais         NaN        NaN
# 5                                     Schwarzenberg        NaN        NaN
# 6                                          Heugasse        NaN        NaN
# 7                                         Belvedere        NaN        NaN
# 8                             k. k. Gemäldegallerie        NaN        NaN
# 9              Garten für die österreichische Flora        NaN        NaN
# 10                                Ambraser Sammlung        NaN        NaN
# 11                  Kabinet äghptischer Alterthümer        NaN        NaN
# 12                                unteren Belvedere        NaN        NaN
# 13                        Hauptstraße der Vorstadt         NaN        NaN
# 14                                          Rennweg  16.379695  48.197128
# 15          Kirche und Kloster der  Salesianerinnen        NaN        NaN
# 16                       MiIitär=Medikamenten=Regie        NaN        NaN
# 17                              botanischen Garten.        NaN        NaN
# 18                                 ViIIa Metternich        NaN        NaN
# 19                                 Neustädter Kanal        NaN        NaN
# 20                   Palais der italienischen Garde        NaN        NaN
# 21                                      Haltergasse        NaN        NaN
# 22  Versuchsgarten den Landwirthschaftsgesellschaft        NaN        NaN
# 23                 Garten der Gartenbaugesellschaft        NaN        NaN
# 24                                            Kanal        NaN        NaN
# 25                             Thierarznei=Jnstitut        NaN        NaN
# 26                                  Kanonenbohrerei        NaN        NaN
# 27                                         Münzhaus        NaN        NaN
# 28                                   Jnvalidenhause        NaN        NaN
# 29                                       Wienbrücke        NaN        NaN
# 30                                       tubenthor   16.378590  48.207739
# 31                                     Stadt London        NaN        NaN
# 32                                       Hauptmauth        NaN        NaN
# 33                                     goldene Ente        NaN        NaN
# 34                                 König von Ungarn        NaN        NaN
# 35                                    Schulenstraße        NaN        NaN
# 36                                         Herrnals        NaN        NaN
# 37                                    Türkenschanze        NaN        NaN
# 38                                         Dornbach        NaN        NaN
# 39                 Parke des  Fürsten Schwarzenberg        NaN        NaN
# 40                                           Hameau        NaN        NaN

# %%
place_coord['SHAPE'] = place_coord['SHAPE'].str.replace(r'POINT', '', regex=True)
place_coord['SHAPE'] = place_coord['SHAPE'].str.replace(r'\)', '', regex=True)
place_coord[['Longitude', 'Latitude']] = place_coord['SHAPE'].str.extract('(\d+.\d+)\s(\d+.\d+)', expand=True)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# <>:3: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\sarah\AppData\Local\Temp\ipykernel_16208\1291391956.py:3: SyntaxWarning: invalid escape sequence '\d'
#   place_coord[['Longitude', 'Latitude']] = place_coord['SHAPE'].str.extract('(\d+.\d+)\s(\d+.\d+)', expand=True)

# %%
joined_places = pd.merge(place_coord, place_Sth_coord, left_index=True, right_index=True)
joined_places = joined_places.drop(columns=["NEUE_NAMEN_y", "SHAPE"])

# %%
joined_places
# Out:
#                                        NEUE_NAMEN_x  \
# 0                                    Kärnthnerthore
# 1                                  große Wienbrücke
# 2                                       Karlskirche
# 3                                        Martinolli
# 4                                           Palais
# 5                                     Schwarzenberg
# 6                                          Heugasse
# 7                                         Belvedere
# 8                             k. k. Gemäldegallerie
# 9              Garten für die österreichische Flora
# 10                                Ambraser Sammlung
# 11                  Kabinet äghptischer Alterthümer
# 12                                unteren Belvedere
# 13                        Hauptstraße der Vorstadt
# 14                                          Rennweg
# 15          Kirche und Kloster der  Salesianerinnen
# 16                       MiIitär=Medikamenten=Regie
# 17                              botanischen Garten.
# 18                                 ViIIa Metternich
# 19                                 Neustädter Kanal
# 20                   Palais der italienischen Garde
# 21                                      Haltergasse
# 22  Versuchsgarten den Landwirthschaftsgesellschaft
# 23                 Garten der Gartenbaugesellschaft
# 24                                            Kanal
# 25                             Thierarznei=Jnstitut
# 26                                  Kanonenbohrerei
# 27                                         Münzhaus
# 28                                   Jnvalidenhause
# 29                                       Wienbrücke
# 30                                       tubenthor
# 31                                     Stadt London
# 32                                       Hauptmauth
# 33                                     goldene Ente
# 34                                 König von Ungarn
# 35                                    Schulenstraße
# 36                                         Herrnals
# 37                                    Türkenschanze
# 38                                         Dornbach
# 39                 Parke des  Fürsten Schwarzenberg
# 40                                           Hameau
#
#                                       ADRESSE         Longitude_x  \
# 0                                         NaN                 NaN
# 1                                         NaN                 NaN
# 2                  04., Karlsplatz 10(KIRCHE)   16.37186617386608
# 3                                         NaN                 NaN
# 4                                         NaN                 NaN
# 5            17., Schwarzenbergallee B Obj. 1   16.27650120252374
# 6                          10., Scheugasse 13  16.378672594075592
# 7           03., Prinz-Eugen-Straße 27 Obj. 8  16.380340127652488
# 8                                         NaN                 NaN
# 9                                         NaN                 NaN
# 10                                        NaN                 NaN
# 11                                        NaN                 NaN
# 12                             03., Rennweg 6   16.37984013304525
# 13                                        NaN                 NaN
# 14                        03., Eslarngasse 29  16.392141649460786
# 15                                        NaN                 NaN
# 16                                        NaN                 NaN
# 17  03., Jacquingasse 8-10(NIEDERL.BOTSCHAFT)  16.383468107371698
# 18                                        NaN                 NaN
# 19                                        NaN                 NaN
# 20                                        NaN                 NaN
# 21                     19., Boschstraße 19/64  16.365131105465572
# 22                                        NaN                 NaN
# 23                                        NaN                 NaN
# 24                                        NaN                 NaN
# 25                                        NaN                 NaN
# 26                                        NaN                 NaN
# 27                                        NaN                 NaN
# 28                                        NaN                 NaN
# 29                                        NaN                 NaN
# 30                          01., Wollzeile 17  16.376276583298328
# 31            02., Kratky-Baschik-Weg STAENDE  16.399143826918255
# 32                                        NaN                 NaN
# 33                                        NaN                 NaN
# 34                                        NaN                 NaN
# 35                        01., Wollzeile 12/2  16.375541269077072
# 36                   17., Promenadegasse 22/5   16.29294515530563
# 37  18., Türkenschanzpark P TEMPORAERER MARKT  16.333559875623802
# 38                                        NaN                 NaN
# 39                                        NaN                 NaN
# 40                       19., Hameaustraße 31  16.293139195977368
#
#             Latitude_x  Longitude_y  Latitude_y
# 0                  NaN          NaN         NaN
# 1                  NaN          NaN         NaN
# 2    48.19824509903096          NaN         NaN
# 3                  NaN    16.374924   48.209951
# 4                  NaN          NaN         NaN
# 5   48.241954429710525          NaN         NaN
# 6   48.179722812509716          NaN         NaN
# 7    48.19424811295102          NaN         NaN
# 8                  NaN          NaN         NaN
# 9                  NaN          NaN         NaN
# 10                 NaN          NaN         NaN
# 11                 NaN          NaN         NaN
# 12   48.19656810152272          NaN         NaN
# 13                 NaN          NaN         NaN
# 14   48.19310095566648    16.379695   48.197128
# 15                 NaN          NaN         NaN
# 16                 NaN          NaN         NaN
# 17   48.19080212731889          NaN         NaN
# 18                 NaN          NaN         NaN
# 19                 NaN          NaN         NaN
# 20                 NaN          NaN         NaN
# 21   48.25174063455336          NaN         NaN
# 22                 NaN          NaN         NaN
# 23                 NaN          NaN         NaN
# 24                 NaN          NaN         NaN
# 25                 NaN          NaN         NaN
# 26                 NaN          NaN         NaN
# 27                 NaN          NaN         NaN
# 28                 NaN          NaN         NaN
# 29                 NaN          NaN         NaN
# 30   48.20862277651324    16.378590   48.207739
# 31  48.216952048263224          NaN         NaN
# 32                 NaN          NaN         NaN
# 33                 NaN          NaN         NaN
# 34                 NaN          NaN         NaN
# 35   48.20820990827117          NaN         NaN
# 36   48.23140778909098          NaN         NaN
# 37   48.23511373039098          NaN         NaN
# 38                 NaN          NaN         NaN
# 39                 NaN          NaN         NaN
# 40   48.25192171922327          NaN         NaN

# %%
matches_sun, matches_mon = table_comparer(joined_places)

# %%
matches_sun
# Out:
#       NEUE_NAMEN_x                          ADRESSE_x         Longitude_x  \
# 0   Kärnthnerthore                                NaN                 NaN
# 1      Karlskirche         04., Karlsplatz 10(KIRCHE)   16.37186617386608
# 2      Karlskirche         04., Karlsplatz 10(KIRCHE)   16.37186617386608
# 3      Karlskirche         04., Karlsplatz 10(KIRCHE)   16.37186617386608
# 4        Belvedere  03., Prinz-Eugen-Straße 27 Obj. 8  16.380340127652488
# 5        Belvedere  03., Prinz-Eugen-Straße 27 Obj. 8  16.380340127652488
# 6          Rennweg                03., Eslarngasse 29  16.392141649460786
# 7            Kanal                                NaN                 NaN
# 8       Hauptmauth                                NaN                 NaN
# 9       Hauptmauth                                NaN                 NaN
# 10        Dornbach                                NaN                 NaN
#
#            Latitude_x  Longitude_y  Latitude_y  \
# 0                 NaN          NaN         NaN
# 1   48.19824509903096          NaN         NaN
# 2   48.19824509903096          NaN         NaN
# 3   48.19824509903096          NaN         NaN
# 4   48.19424811295102          NaN         NaN
# 5   48.19424811295102          NaN         NaN
# 6   48.19310095566648    16.379695   48.197128
# 7                 NaN          NaN         NaN
# 8                 NaN          NaN         NaN
# 9                 NaN          NaN         NaN
# 10                NaN          NaN         NaN
#
#                             ADRESSE_y        Sicherheit  Longitude   Latitude  \
# 0              01, Kärntner Straße 51              hoch  16.370534  48.203303
# 1          04., Karlsplatz 10(KIRCHE)              hoch  16.371866  48.198245
# 2          04., Karlsplatz 10(KIRCHE)              hoch  16.371866  48.198245
# 3          04., Karlsplatz 10(KIRCHE)              hoch  16.371866  48.198245
# 4   03., Prinz-Eugen-Straße 27 Obj. 8              hoch  16.380340  48.194248
# 5   03., Prinz-Eugen-Straße 27 Obj. 8              hoch  16.380340  48.194248
# 6                 03., Eslarngasse 29            mittel  16.392142  48.193101
# 7                                 NaN  sehr niedrig (f)  16.349722  48.075278
# 8                                 NaN              hoch  16.379973  48.209980
# 9         03., Dominikanerbastei 9-13              hoch  16.379973  48.209980
# 10                                NaN               NaN        NaN        NaN
#
#                                Quelle  \
# 0   Wien Geschichte Wiki, Google Maps
# 1                       KulturwikiOGD
# 2                       KulturwikiOGD
# 3                       KulturwikiOGD
# 4                       KulturwikiOGD
# 5                       KulturwikiOGD
# 6   Gazetteer_Steinhausenplan_V5_auto
# 7                  Wikipedia, GeoHack
# 8                   QGIS - Estimation
# 9                   QGIS - Estimation
# 10                                NaN
#
#                                                   URL
# 0   https://www.geschichtewiki.wien.gv.at/K%C3%A4r...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   https://geohack.toolforge.org/geohack.php?page...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN

# %%
matches_mon
# Out:
#   NEUE_NAMEN_x ADRESSE_x Longitude_x_x Latitude_x_x  Longitude_y  Latitude_y  \
# 0   Hauptmauth       NaN           NaN          NaN          NaN         NaN
#
#   ADRESSE_y Sicherheit  Longitude_x_y  Latitude_x_y                 Quelle  \
# 0       NaN       hoch       16.37906     48.210195  Steinhausen Gazetteer
#
#    URL
# 0  NaN

# %%
joined_places.to_excel('../Data/Dienstag/joined_Dienstag_coord.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 joined_places.to_excel('../Data/Dienstag/joined_Dienstag_coord.xlsx')
#
# File c:\Users\sarah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:2345, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2332 from pandas.io.formats.excel import ExcelFormatter
#    2334 formatter = ExcelFormatter(
#    2335     df,
#    2336     na_rep=na_rep,
#    (...)
#    2343     inf_rep=inf_rep,
#    2344 )
# -> 2345 formatter.write(
#    2346     excel_writer,
#    2347     sheet_name=sheet_name,
#    2348     startrow=startrow,
#    2349     startcol=startcol,
#    2350     freeze_panes=freeze_panes,
#    2351     engine=engine,
#    2352     storage_options=storage_options,
#    2353     engine_kwargs=engine_kwargs,
#    2354 )
#
# File c:\Users\sarah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\formats\excel.py:946, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     942     need_save = False
#     943 else:
#     944     # error: Cannot instantiate abstract class 'ExcelWriter' with abstract
#     945     # attributes 'engine', 'save', 'supported_extensions' and 'write_cells'
# --> 946     writer = ExcelWriter(  # type: ignore[abstract]
#     947         writer,
#     948         engine=engine,
#     949         storage_options=storage_options,
#     950         engine_kwargs=engine_kwargs,
#     951     )
#     952     need_save = True
#     954 try:
#
# File c:\Users\sarah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_xlsxwriter.py:205, in XlsxWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     202 if mode == "a":
#     203     raise ValueError("Append mode is not supported with xlsxwriter!")
# --> 205 super().__init__(
#     206     path,
#     207     engine=engine,
#     208     date_format=date_format,
#     209     datetime_format=datetime_format,
#     210     mode=mode,
#     211     storage_options=storage_options,
#     212     if_sheet_exists=if_sheet_exists,
#     213     engine_kwargs=engine_kwargs,
#     214 )
#     216 try:
#     217     self._book = Workbook(self._handles.handle, **engine_kwargs)
#
# File c:\Users\sarah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:1263, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1259 self._handles = IOHandles(
#    1260     cast(IO[bytes], path), compression={"compression": None}
#    1261 )
#    1262 if not isinstance(path, ExcelWriter):
# -> 1263     self._handles = get_handle(
#    1264         path, mode, storage_options=storage_options, is_text=False
#    1265     )
#    1266 self._cur_sheet = None
#    1268 if date_format is None:
#
# File c:\Users\sarah\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# PermissionError: [Errno 13] Permission denied: '../Data/Dienstag/joined_Dienstag_coord.xlsx'

# %%
joined_places_nn = pd.read_excel('../Data/Dienstag/joined_Dienstag_coord_nn.xlsx')
joined_places_nn.to_csv('../Data/Dienstag/joined_Dienstag_coord_nn.csv')
