# %%
import re
import pandas as pd

# %%
from os import path
file_path = path.relpath("Data/first_page.txt")

# %%
with open(file_path, encoding='utf8') as file:
    contents = file.read()

# %%
print(contents)
# Out:
# I. Wegweiser. Orientirung in Wien. Rundgang um die Bastei. Wenn es für jeden Reisenden unerläßlich ist, sich in einer fremden Stadt zu orientiren, so ist es we= nigstens in Wien sehr leicht. Der Stephansplatz liegt so ziemlich mitten in der Stadt, und mit Hilfe des Planes wird man bald die Hauptpulsader der innern Stadt kennen lernen; diese führt nämlich vom Burgthor durch die Burg über den Michaels= platz, Kohlmarkt, Graben, Stephans= platz, Bischofs= und Rothenthurmstraße zum Rothenthurmthore, und bildet die Figur einer doppelten Stufe, deren innerer Winkel St. Stephan ist. Zu einer dieser Straßen, auf einen dieser Plätze wird man sich bald finden oder erfragen. — Eine Besteigung des Stephans= thurmes gibt wohl eine vollständige Uebersicht der Stadt und Umgebung, aber zur Orientirung ist sie keineswegs so wesentlich.

# %% [markdown]
# Some things that might pose problems for NER: Some Names are seperated by '=', like Stephans= platz. We can merge them using
# regex, but have to leave out words like 'und' or 'oder' ; tokenizing them with spacy correctly might also work; but we still have the problem
# with und and order distinction

# %%
re.findall('(\w)= (\w)', contents)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\sarah\AppData\Local\Temp\ipykernel_2200\1049048786.py:1: SyntaxWarning: invalid escape sequence '\w'
#   re.findall('(\w)= (\w)', contents)
# [('e', 'n'), ('s', 'p'), ('s', 'p'), ('s', 'u'), ('s', 't')]

# %%
contents_clean = re.sub('(\w)= ([^uo])','\g<1>\g<2>', contents)
print(contents_clean)
# Out:
# I. Wegweiser. Orientirung in Wien. Rundgang um die Bastei. Wenn es für jeden Reisenden unerläßlich ist, sich in einer fremden Stadt zu orientiren, so ist es wenigstens in Wien sehr leicht. Der Stephansplatz liegt so ziemlich mitten in der Stadt, und mit Hilfe des Planes wird man bald die Hauptpulsader der innern Stadt kennen lernen; diese führt nämlich vom Burgthor durch die Burg über den Michaelsplatz, Kohlmarkt, Graben, Stephansplatz, Bischofs= und Rothenthurmstraße zum Rothenthurmthore, und bildet die Figur einer doppelten Stufe, deren innerer Winkel St. Stephan ist. Zu einer dieser Straßen, auf einen dieser Plätze wird man sich bald finden oder erfragen. — Eine Besteigung des Stephansthurmes gibt wohl eine vollständige Uebersicht der Stadt und Umgebung, aber zur Orientirung ist sie keineswegs so wesentlich.
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\sarah\AppData\Local\Temp\ipykernel_2200\604090336.py:1: SyntaxWarning: invalid escape sequence '\w'
#   contents_clean = re.sub('(\w)= ([^uo])','\g<1>\g<2>', contents)
# C:\Users\sarah\AppData\Local\Temp\ipykernel_2200\604090336.py:1: SyntaxWarning: invalid escape sequence '\g'
#   contents_clean = re.sub('(\w)= ([^uo])','\g<1>\g<2>', contents)

# %% [markdown]
# Checking some simple statistics:

# %%
list_words = contents_clean.split()
print(len(list_words))

import string
list_words = [w.strip(string.punctuation) for w in list_words]
# Out:
# 125

# %%
word_freq = {}
for word in list_words:
    word_freq[word] = word_freq.get(word, 0) + 1
print(word_freq)

# %% [markdown]
# Getting started with spaCy: I'm using a tutorial from the internet... :)

# %%
import spacy
nlp = spacy.load("de_core_news_sm")

# %%
introduction_doc = nlp(contents_clean)
print ([token.text for token in introduction_doc])
# Out:
# ['I.', 'Wegweiser', '.', 'Orientirung', 'in', 'Wien', '.', 'Rundgang', 'um', 'die', 'Bastei', '.', 'Wenn', 'es', 'für', 'jeden', 'Reisenden', 'unerläßlich', 'ist', ',', 'sich', 'in', 'einer', 'fremden', 'Stadt', 'zu', 'orientiren', ',', 'so', 'ist', 'es', 'wenigstens', 'in', 'Wien', 'sehr', 'leicht', '.', 'Der', 'Stephansplatz', 'liegt', 'so', 'ziemlich', 'mitten', 'in', 'der', 'Stadt', ',', 'und', 'mit', 'Hilfe', 'des', 'Planes', 'wird', 'man', 'bald', 'die', 'Hauptpulsader', 'der', 'innern', 'Stadt', 'kennen', 'lernen', ';', 'diese', 'führt', 'nämlich', 'vom', 'Burgthor', 'durch', 'die', 'Burg', 'über', 'den', 'Michaelsplatz', ',', 'Kohlmarkt', ',', 'Graben', ',', 'Stephansplatz', ',', 'Bischofs=', 'und', 'Rothenthurmstraße', 'zum', 'Rothenthurmthore', ',', 'und', 'bildet', 'die', 'Figur', 'einer', 'doppelten', 'Stufe', ',', 'deren', 'innerer', 'Winkel', 'St.', 'Stephan', 'ist', '.', 'Zu', 'einer', 'dieser', 'Straßen', ',', 'auf', 'einen', 'dieser', 'Plätze', 'wird', 'man', 'sich', 'bald', 'finden', 'oder', 'erfragen', '.', '—', 'Eine', 'Besteigung', 'des', 'Stephansthurmes', 'gibt', 'wohl', 'eine', 'vollständige', 'Uebersicht', 'der', 'Stadt', 'und', 'Umgebung', ',', 'aber', 'zur', 'Orientirung', 'ist', 'sie', 'keineswegs', 'so', 'wesentlich', '.']

# %% [markdown]
# Trying to see if spacy detects sentences correctly:

# %%
sentences = list(introduction_doc.sents)
print(sentences)
# Out:
# [I. Wegweiser., Orientirung in Wien., Rundgang um die Bastei., Wenn es für jeden Reisenden unerläßlich ist, sich in einer fremden Stadt zu orientiren, so ist es wenigstens in Wien sehr leicht., Der Stephansplatz liegt so ziemlich mitten in der Stadt, und mit Hilfe des Planes wird man bald die Hauptpulsader der innern Stadt kennen lernen;, diese führt nämlich vom Burgthor durch die Burg über den Michaelsplatz, Kohlmarkt, Graben, Stephansplatz, Bischofs= und Rothenthurmstraße zum Rothenthurmthore, und bildet die Figur einer doppelten Stufe, deren innerer Winkel St. Stephan ist., Zu einer dieser Straßen, auf einen dieser Plätze wird man sich bald finden oder erfragen., — Eine Besteigung des Stephansthurmes gibt wohl eine vollständige Uebersicht der Stadt und Umgebung, aber zur Orientirung ist sie keineswegs so wesentlich.]

# %% [markdown]
# Taking ; out of the sentence - dividing

# %%
from spacy.language import Language

# %%
@Language.component("set_custom_boundaries")
def set_custom_boundaries(doc):
    for token in doc[:-1]:
        if token.text == ";":
            doc[token.i + 1].is_sent_start = False
            return doc

# %%
custom_nlp = spacy.load("de_core_news_sm")
custom_nlp.add_pipe("set_custom_boundaries", before="parser")
custom_intro = custom_nlp(contents_clean)
custom_sentences = list(custom_intro.sents)
for sentence in custom_sentences:
    print(sentence)
# Out:
# I. Wegweiser.
# Orientirung in Wien.
# Rundgang um die Bastei.
# Wenn es für jeden Reisenden unerläßlich ist, sich in einer fremden Stadt zu orientiren, so ist es wenigstens in Wien sehr leicht.
# Der Stephansplatz liegt so ziemlich mitten in der Stadt, und mit Hilfe des Planes wird man bald die Hauptpulsader der innern Stadt kennen lernen; diese führt nämlich vom Burgthor durch die Burg über den Michaelsplatz, Kohlmarkt, Graben, Stephansplatz, Bischofs= und Rothenthurmstraße zum Rothenthurmthore, und bildet die Figur einer doppelten Stufe, deren innerer Winkel St. Stephan ist.
# Zu einer dieser Straßen, auf einen dieser Plätze wird man sich bald finden oder erfragen.
# — Eine Besteigung des Stephansthurmes gibt wohl eine vollständige Uebersicht der Stadt und Umgebung, aber zur Orientirung ist sie keineswegs so wesentlich.

# %% [markdown]
# Trying to remove stop words and punctuation:

# %%
print ([token for token in introduction_doc if not (token.is_stop or token.is_punct)])
# Out:
# [I., Wegweiser, Orientirung, Wien, Rundgang, Bastei, Reisenden, unerläßlich, fremden, Stadt, orientiren, Wien, Stephansplatz, liegt, ziemlich, mitten, Stadt, Hilfe, Planes, Hauptpulsader, innern, Stadt, kennen, lernen, führt, nämlich, Burgthor, Burg, Michaelsplatz, Kohlmarkt, Graben, Stephansplatz, Bischofs=, Rothenthurmstraße, Rothenthurmthore, bildet, Figur, doppelten, Stufe, innerer, Winkel, St., Stephan, Straßen, Plätze, finden, erfragen, Besteigung, Stephansthurmes, vollständige, Uebersicht, Stadt, Umgebung, Orientirung, keineswegs, wesentlich]

# %% [markdown]
# Trying Lemmatization (not 100 Percent accurate, I think):

# %%
#check to see if the original word is different from the lemma, and if it is, print both the original word and its lemma
for token in introduction_doc: 
    if str(token) != str(token.lemma_):
        print(f"{str(token):>20} : {str(token.lemma_)}")
# Out:
#                    . : --
#                    . : --
#                  die : der
#                    . : --
#                 Wenn : wenn
#                jeden : jeder
#            Reisenden : reisend
#                  ist : sein
#                    , : --
#                einer : ein
#              fremden : fremd
#                    , : --
#                  ist : sein
#                    . : --
#                  Der : der
#                liegt : liegen
#                    , : --
#                  des : der
#               Planes : Plan
#                 wird : werden
#                  die : der
#                    ; : --
#                diese : dieser
#                führt : führen
#                  vom : von
#                  die : der
#                  den : der
#                    , : --
#                    , : --
#                    , : --
#                    , : --
#                  zum : zu
#                    , : --
#               bildet : bilden
#                  die : der
#                einer : ein
#            doppelten : doppelt
#                    , : --
#                deren : der
#                  ist : sein
#                    . : --
#                   Zu : zu
#                einer : ein
#              Straßen : Straße
#                    , : --
#                einen : einer
#               Plätze : Platz
#                 wird : werden
#                    . : --
#                    — : --
#                 Eine : ein
#                  des : der
#      Stephansthurmes : Stephansthurm
#                 gibt : geben
#                 eine : ein
#         vollständige : vollständig
#                    , : --
#                  zur : zu
#                  ist : sein
#                    . : --

# %% [markdown]
# Trying Word Frequency:

# %%
from collections import Counter

# %%
words = [token.text for token in introduction_doc if not (token.is_stop or token.is_punct)]
print(Counter(words).most_common(3))
# Out:
# [('Stadt', 4), ('Orientirung', 2), ('Wien', 2)]

# %% [markdown]
# Trying POS-tagging:

# %%
for token in introduction_doc:
    print(f"""TOKEN: {str(token)}
          =====
          TAG: {str(token.tag_):10} POS: {token.pos_}
          EXPLANATION: {spacy.explain(token.tag_)}""")
# Out:
# TOKEN: I.
#           =====
#           TAG: ADJA       POS: X
#           EXPLANATION: adjective, attributive
# TOKEN: Wegweiser
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: Orientirung
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: in
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: Wien
#           =====
#           TAG: NE         POS: PROPN
#           EXPLANATION: proper noun
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: Rundgang
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: um
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: die
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Bastei
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: Wenn
#           =====
#           TAG: KOUS       POS: SCONJ
#           EXPLANATION: subordinate conjunction with sentence
# TOKEN: es
#           =====
#           TAG: PPER       POS: PRON
#           EXPLANATION: non-reflexive personal pronoun
# TOKEN: für
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: jeden
#           =====
#           TAG: PIAT       POS: DET
#           EXPLANATION: attributive indefinite pronoun without determiner
# TOKEN: Reisenden
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: unerläßlich
#           =====
#           TAG: ADJD       POS: ADV
#           EXPLANATION: adjective, adverbial or predicative
# TOKEN: ist
#           =====
#           TAG: VAFIN      POS: AUX
#           EXPLANATION: finite verb, auxiliary
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: sich
#           =====
#           TAG: PRF        POS: PRON
#           EXPLANATION: reflexive personal pronoun
# TOKEN: in
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: einer
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: fremden
#           =====
#           TAG: ADJA       POS: ADJ
#           EXPLANATION: adjective, attributive
# TOKEN: Stadt
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: zu
#           =====
#           TAG: PTKZU      POS: PART
#           EXPLANATION: "zu" before infinitive
# TOKEN: orientiren
#           =====
#           TAG: VVINF      POS: VERB
#           EXPLANATION: infinitive, full
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: so
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: ist
#           =====
#           TAG: VAFIN      POS: AUX
#           EXPLANATION: finite verb, auxiliary
# TOKEN: es
#           =====
#           TAG: PPER       POS: PRON
#           EXPLANATION: non-reflexive personal pronoun
# TOKEN: wenigstens
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: in
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: Wien
#           =====
#           TAG: NE         POS: PROPN
#           EXPLANATION: proper noun
# TOKEN: sehr
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: leicht
#           =====
#           TAG: ADJD       POS: ADV
#           EXPLANATION: adjective, adverbial or predicative
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: Der
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Stephansplatz
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: liegt
#           =====
#           TAG: VVFIN      POS: VERB
#           EXPLANATION: finite verb, full
# TOKEN: so
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: ziemlich
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: mitten
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: in
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: der
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Stadt
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: und
#           =====
#           TAG: KON        POS: CCONJ
#           EXPLANATION: coordinate conjunction
# TOKEN: mit
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: Hilfe
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: des
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Planes
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: wird
#           =====
#           TAG: VAFIN      POS: AUX
#           EXPLANATION: finite verb, auxiliary
# TOKEN: man
#           =====
#           TAG: PIS        POS: PRON
#           EXPLANATION: substituting indefinite pronoun
# TOKEN: bald
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: die
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Hauptpulsader
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: der
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: innern
#           =====
#           TAG: ADJA       POS: ADJ
#           EXPLANATION: adjective, attributive
# TOKEN: Stadt
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: kennen
#           =====
#           TAG: VVINF      POS: VERB
#           EXPLANATION: infinitive, full
# TOKEN: lernen
#           =====
#           TAG: VVINF      POS: VERB
#           EXPLANATION: infinitive, full
# TOKEN: ;
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: diese
#           =====
#           TAG: PDS        POS: PRON
#           EXPLANATION: substituting demonstrative pronoun
# TOKEN: führt
#           =====
#           TAG: VVFIN      POS: VERB
#           EXPLANATION: finite verb, full
# TOKEN: nämlich
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: vom
#           =====
#           TAG: APPRART    POS: ADP
#           EXPLANATION: preposition with article
# TOKEN: Burgthor
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: durch
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: die
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Burg
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: über
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: den
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Michaelsplatz
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: Kohlmarkt
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: Graben
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: Stephansplatz
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: Bischofs=
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: und
#           =====
#           TAG: KON        POS: CCONJ
#           EXPLANATION: coordinate conjunction
# TOKEN: Rothenthurmstraße
#           =====
#           TAG: NE         POS: NOUN
#           EXPLANATION: proper noun
# TOKEN: zum
#           =====
#           TAG: APPRART    POS: ADP
#           EXPLANATION: preposition with article
# TOKEN: Rothenthurmthore
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: und
#           =====
#           TAG: KON        POS: CCONJ
#           EXPLANATION: coordinate conjunction
# TOKEN: bildet
#           =====
#           TAG: VVFIN      POS: VERB
#           EXPLANATION: finite verb, full
# TOKEN: die
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Figur
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: einer
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: doppelten
#           =====
#           TAG: ADJA       POS: ADJ
#           EXPLANATION: adjective, attributive
# TOKEN: Stufe
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: deren
#           =====
#           TAG: PRELAT     POS: DET
#           EXPLANATION: attributive relative pronoun
# TOKEN: innerer
#           =====
#           TAG: ADJA       POS: ADJ
#           EXPLANATION: adjective, attributive
# TOKEN: Winkel
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: St.
#           =====
#           TAG: NE         POS: PROPN
#           EXPLANATION: proper noun
# TOKEN: Stephan
#           =====
#           TAG: NE         POS: PROPN
#           EXPLANATION: proper noun
# TOKEN: ist
#           =====
#           TAG: VAFIN      POS: AUX
#           EXPLANATION: finite verb, auxiliary
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: Zu
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: einer
#           =====
#           TAG: PIS        POS: PRON
#           EXPLANATION: substituting indefinite pronoun
# TOKEN: dieser
#           =====
#           TAG: PDAT       POS: DET
#           EXPLANATION: attributive demonstrative pronoun
# TOKEN: Straßen
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: auf
#           =====
#           TAG: APPR       POS: ADP
#           EXPLANATION: preposition; circumposition left
# TOKEN: einen
#           =====
#           TAG: PIS        POS: PRON
#           EXPLANATION: substituting indefinite pronoun
# TOKEN: dieser
#           =====
#           TAG: PDAT       POS: DET
#           EXPLANATION: attributive demonstrative pronoun
# TOKEN: Plätze
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: wird
#           =====
#           TAG: VAFIN      POS: AUX
#           EXPLANATION: finite verb, auxiliary
# TOKEN: man
#           =====
#           TAG: PIS        POS: PRON
#           EXPLANATION: substituting indefinite pronoun
# TOKEN: sich
#           =====
#           TAG: PRF        POS: PRON
#           EXPLANATION: reflexive personal pronoun
# TOKEN: bald
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: finden
#           =====
#           TAG: VVINF      POS: VERB
#           EXPLANATION: infinitive, full
# TOKEN: oder
#           =====
#           TAG: KON        POS: CCONJ
#           EXPLANATION: coordinate conjunction
# TOKEN: erfragen
#           =====
#           TAG: VVPP       POS: VERB
#           EXPLANATION: perfect participle, full
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark
# TOKEN: —
#           =====
#           TAG: $(         POS: PUNCT
#           EXPLANATION: other sentence-internal punctuation mark
# TOKEN: Eine
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Besteigung
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: des
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Stephansthurmes
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: gibt
#           =====
#           TAG: VVFIN      POS: VERB
#           EXPLANATION: finite verb, full
# TOKEN: wohl
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: eine
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: vollständige
#           =====
#           TAG: ADJA       POS: ADJ
#           EXPLANATION: adjective, attributive
# TOKEN: Uebersicht
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: der
#           =====
#           TAG: ART        POS: DET
#           EXPLANATION: definite or indefinite article
# TOKEN: Stadt
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: und
#           =====
#           TAG: KON        POS: CCONJ
#           EXPLANATION: coordinate conjunction
# TOKEN: Umgebung
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ,
#           =====
#           TAG: $,         POS: PUNCT
#           EXPLANATION: comma
# TOKEN: aber
#           =====
#           TAG: KON        POS: CCONJ
#           EXPLANATION: coordinate conjunction
# TOKEN: zur
#           =====
#           TAG: APPRART    POS: ADP
#           EXPLANATION: preposition with article
# TOKEN: Orientirung
#           =====
#           TAG: NN         POS: NOUN
#           EXPLANATION: noun, singular or mass
# TOKEN: ist
#           =====
#           TAG: VAFIN      POS: AUX
#           EXPLANATION: finite verb, auxiliary
# TOKEN: sie
#           =====
#           TAG: PPER       POS: PRON
#           EXPLANATION: non-reflexive personal pronoun
# TOKEN: keineswegs
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: so
#           =====
#           TAG: ADV        POS: ADV
#           EXPLANATION: adverb
# TOKEN: wesentlich
#           =====
#           TAG: ADJD       POS: ADV
#           EXPLANATION: adjective, adverbial or predicative
# TOKEN: .
#           =====
#           TAG: $.         POS: PUNCT
#           EXPLANATION: sentence-final punctuation mark

# %%
nouns = []
for token in introduction_doc:
    if token.pos_ == "PROPN":
        nouns.append(token)

for noun in nouns:
    print(noun)
# Out:
# Wien
# Wien
# St.
# Stephan

# %% [markdown]
# Why are those Proper Names, but Stephansplatz isn't? Should i use rule-based matching for that?
# Maybe I can use rule-based matching for my Bischofs= straße problem?

# %% [markdown]
# Things I left out in the tutorial (for now):
# - Rule-based Matching
# - Dependency Parsing
# - Tree and Subtree Navigation
# - Verb Phrase Detection

# %%
for noun_phrase in introduction_doc.noun_chunks:
    print (noun_phrase)
# Out:
# I. Wegweiser
# Orientirung
# Wien
# Rundgang
# die Bastei
# es
# jeden Reisenden
# sich
# einer fremden Stadt
# es
# Wien
# Der Stephansplatz
# der Stadt
# Hilfe
# des Planes
# man
# die Hauptpulsader
# der innern Stadt
# diese
# Burgthor
# die Burg
# den Michaelsplatz
# Kohlmarkt
# Graben
# Stephansplatz
# Bischofs=
# Rothenthurmstraße
# Rothenthurmthore
# die Figur
# einer doppelten Stufe
# deren innerer Winkel St. Stephan
# einer
# dieser Straßen
# einen
# dieser Plätze
# man
# sich
# Eine Besteigung
# des Stephansthurmes
# eine vollständige Uebersicht
# der Stadt
# Umgebung
# Orientirung
# sie

# %% [markdown]
# First tries of Named-Entity-Recognition:

# %%
for phrase in introduction_doc.ents:
    print(f"""{phrase.text = }
    {phrase.start_char = }
    {phrase.end_char = }
    {phrase.label_ = }
    spacy.explain('{phrase.label_}') = {spacy.explain(phrase.label_)}""")
# Out:
# phrase.text = 'I. Wegweiser'
#     phrase.start_char = 0
#     phrase.end_char = 12
#     phrase.label_ = 'PER'
#     spacy.explain('PER') = Named person or family.
# phrase.text = 'Wien'
#     phrase.start_char = 29
#     phrase.end_char = 33
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Wien'
#     phrase.start_char = 171
#     phrase.end_char = 175
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Stephansplatz'
#     phrase.start_char = 193
#     phrase.end_char = 206
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Stadt'
#     phrase.start_char = 239
#     phrase.end_char = 244
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Planes'
#     phrase.start_char = 264
#     phrase.end_char = 270
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Burgthor'
#     phrase.start_char = 359
#     phrase.end_char = 367
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Kohlmarkt'
#     phrase.start_char = 407
#     phrase.end_char = 416
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Graben'
#     phrase.start_char = 418
#     phrase.end_char = 424
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Stephansplatz'
#     phrase.start_char = 426
#     phrase.end_char = 439
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Bischofs='
#     phrase.start_char = 441
#     phrase.end_char = 450
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'Rothenthurmstraße'
#     phrase.start_char = 455
#     phrase.end_char = 472
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
# phrase.text = 'St. Stephan'
#     phrase.start_char = 560
#     phrase.end_char = 571
#     phrase.label_ = 'LOC'
#     spacy.explain('LOC') = Non-GPE locations, mountain ranges, bodies of water
